# %%
# standard
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
# statsmodels
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA
# os
import os
# sklearn
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
# tf
import tensorflow as tf
# keras
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Layer, GRU, LSTM, SimpleRNN, Dense, Activation, Dropout
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
from keras import optimizers
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
from keras.regularizers import l1,l2
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Import btc
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Make pd df
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NN - 434/btc.csv')

# %%
df.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0            4.39
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# Drop extraneous columns
df.drop(['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume_(BTC)', 'Volume_(Currency)'], axis = 1, inplace = True)
# Drop bottom 3m rows and top 800k
df.drop(df.index[:3000000], axis = 0, inplace = True)
df.drop(df.index[4000000:], axis = 0, inplace = True)
# Reset index; drop column
df.reset_index(drop = True, inplace = True)
# Backfill na's
df.fillna(method = 'backfill', inplace = True)

# %%
# RNN target/features
features = ['Weighted_Price']
target = 'Weighted_Price'

# %%
# Split train sets
train_weight = 0.8
df_split = int( len(df) * train_weight )

train = df.iloc[:df_split]
test = df.iloc[df_split:]

# %%
# Scaling parameters
mu = float( train[features].mean() )
sigma = float( train[features].std() )

# Scale data
train = train[features].apply( lambda x: (x - mu) / sigma )
test = test[features].apply( lambda x: (x - mu) / sigma )

# %%
'''
Function for reshaping data into one-step ahead time series prediction format
    value: feature value to be lagged
    n_steps: number of steps/sequence length
    n_steps_ahead: forecasting horizon
'''

def get_lagged_features(value, n_steps, n_steps_ahead):
    lag_list = []
    for lag in range(n_steps + n_steps_ahead - 1, n_steps_ahead - 1, -1):
        lag_list.append( value.shift(lag) )
    return pd.concat(lag_list, axis = 1)

# %%
# Number of steps ahead
n_steps_ahead = n_steps = 3

# Transform training input and output data
col_ords = []
for i in range(n_steps):
    for j in range(len(features)):
        col_ords.append(i + j * n_steps)

x_train_list = []
for f in features:
    x_train_reg = get_lagged_features(train, n_steps, n_steps).dropna()
    x_train_list.append(x_train_reg)
x_train_reg = pd.concat(x_train_list, axis = 1)
        
x_train_reg = x_train_reg.iloc[:, col_ords]
y_train_reg = train.loc[x_train_reg.index, [target]].values
x_train_reg = np.reshape( x_train_reg.values, ( x_train_reg.shape[0], int( x_train_reg.shape[1] / len(features)), len(features) ) )
y_train_reg = np.reshape( y_train_reg, (y_train_reg.shape[0], 1, 1))

# %%
# Transform test input and output data
x_test_list = []
for f in features:
    x_test_reg = get_lagged_features(test, n_steps, n_steps).dropna()
    x_test_list.append(x_test_reg)
x_test_reg = pd.concat(x_test_list, axis = 1)

x_test_reg = x_test_reg.iloc[:, col_ords]
y_test_reg = test.loc[x_test_reg.index, [target]].values
x_test_reg = np.reshape( x_test_reg.values, ( x_test_reg.shape[0], int( x_test_reg.shape[1] / len(features)), len(features) ) )
y_test_reg = np.reshape( y_test_reg, (y_test_reg.shape[0], 1, 1))

# %%
# Verify tensor shapes
#   value 1: # of observations
#   value 2: sequence length, or number of lags
#   value 3: dimension of each element in the sequence (x) or output vector (y): this is univariate time analysis, so the dimension of I/O is 1

print(x_train_reg.shape)
print(y_train_reg.shape)
print(x_test_reg.shape)
print(y_test_reg.shape)
# Out:
# (1485896, 3, 1)
# (1485896, 1, 1)
# (371471, 3, 1)
# (371471, 1, 1)

# %%
# Append lagged lists to train data
x_train_reg = pd.concat(x_train_list, axis = 1)
# Reshape
x_train_reg = x_train_reg.iloc[:, col_ords]
y_train_reg = train.loc[x_train_reg.index, [target]].values
x_train_reg = np.reshape( x_train_reg.values, ( x_train_reg.shape[0], int(x_train_reg.shape[1] / len(features)), len(features) ) )

# %%
# Append lagged lists to test data
x_test_reg = pd.concat(x_test_list, axis = 1)
# Reshape
x_test_reg = x_test_reg.iloc[:, col_ords]
y_test_reg = test.loc[x_test_reg.index, [target]].values
x_test_reg = np.reshape( x_test_reg.values, ( x_test_reg.shape[0], int(x_test_reg.shape[1] / len(features)), len(features) ) )

# %%
# Custom activation function
def swish(x):
    return (K.sigmoid(x) * x)

get_custom_objects().update({'swish': Activation(swish)})

# %%
# NN structures - SWISH
def _RNN(data = x_train_reg, n_units = 10, l1_reg = 0.0001, seed = 0, optim = 'adam', dropout = 0):
    model = Sequential()
    model.add( 
        SimpleRNN(n_units,
                  activation = 'swish', 
                  kernel_initializer = keras.initializers.glorot_uniform(seed), 
                  bias_initializer = keras.initializers.glorot_uniform(seed), 
                  recurrent_initializer = keras.initializers.orthogonal(seed), 
                  kernel_regularizer = l1(l1_reg), 
                  input_shape = (data.shape[1], data.shape[-1]),
                  unroll = True,
                  stateful = False) )  
    model.add(
        Dense(1, 
              kernel_initializer = keras.initializers.glorot_uniform(seed), 
              bias_initializer = keras.initializers.glorot_uniform(seed), 
              kernel_regularizer = l1(l1_reg) ) )
    model.compile(loss = 'mean_squared_error', optimizer = optim)
    return model

def _dropout(data = x_train_reg, n_units = 10, l1_reg = 0.0001, seed = 0, optim = 'adam', dropout = 0):
    model = Sequential()
    model.add(
        Dropout(rate = dropout, 
                input_shape = (data.shape[1], data.shape[-1]),
                name = 'Dropout_A') )
    model.add( 
        SimpleRNN(n_units,
                  activation = 'swish', 
                  kernel_initializer = keras.initializers.glorot_uniform(seed), 
                  bias_initializer = keras.initializers.glorot_uniform(seed), 
                  recurrent_initializer = keras.initializers.orthogonal(seed), 
                  kernel_regularizer = l1(l1_reg), 
                  input_shape = (data.shape[1], data.shape[-1]),
                  unroll = True,
                  stateful = False,
                  name = 'RNN_A') )
    model.add(
        Dense(1,
              kernel_initializer = keras.initializers.glorot_uniform(seed), 
              bias_initializer = keras.initializers.glorot_uniform(seed), 
              kernel_regularizer = l1(l1_reg),
              name = 'Dense_A') )
    model.compile(loss = 'mean_squared_error', optimizer = optim)
    return model

# %%
# Hyperparameters
n_epoches = 50
batch_size = 1000

# %%
# NN models
params = {
    'rnn': {'model':'', 'function':_RNN, 'l1_reg':0.0001, 'H':10, 'label':'RNN', 'dropout':0, 'history':'', 'cv_results':''},
    'dropout': {'model':'', 'function':_dropout, 'l1_reg':0.0, 'H':10, 'label':'Dropout RNN', 'dropout':0, 'history':'', 'cv_results':''}
}

# %%
# Implement early stopping monitor to speed up cross validation
es = EarlyStopping(monitor = 'loss', mode = 'min', verbose = 1, patience = 100, min_delta = 1e-7, restore_best_weights = True)

# %%
# Cross-validation parameters
n_units = [14, 16, 18, 20, 22]
l1_reg = [0.000001, 0.000005, 0.00001, 0.00005]
dropout = [0.0005, 0.0001, 0.005, 0.001]
time_series_cv = TimeSeriesSplit(n_splits = 5)
param_grid = {
    'n_units': n_units,
    'l1_reg': l1_reg,
    'dropout': dropout
}

# %%
# Cross-validate NN models
for k in params.keys():
    if k == 'rnn':
        continue

    model = KerasRegressor(build_fn = params[k]['function'], epochs = n_epoches,
                           batch_size = batch_size, verbose = 2)
    grid = GridSearchCV(estimator = model, param_grid = param_grid,
                        cv = time_series_cv, n_jobs = 1, verbose = 2)
    grid_result = grid.fit(x_train_reg[:30000], y_train_reg[:30000], callbacks = [es])

    print("Best score: [ %f ] using param [ %s ]" % (grid_result.best_score_, grid_result.best_params_) )

    mean_scores = grid_result.cv_results_['mean_test_score']
    std_scores = grid_result.cv_results_['std_test_score']
    param_results = grid_result.cv_results_['params']

    for mean, stdev, p in zip(mean_scores, std_scores, param_results):
        print("Mean of  [ %f ] , stdev of [ %f ] using [ %s ]" % (mean, stdev, p) )

    params[k]['cv_results'] = grid_result.cv_results_
    params[k]['H'] = grid_result.best_params_['n_units']
    params[k]['l1_reg'] = grid_result.best_params_['l1_reg']
    params[k]['dropout'] = grid_result.best_params_['dropout']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   import sys
# Streaming output truncated to the last 5000 lines.
# 15/15 - 0s - loss: 0.0051 - 32ms/epoch - 2ms/step
# Epoch 40/50
# 15/15 - 0s - loss: 0.0051 - 35ms/epoch - 2ms/step
# Epoch 41/50
# 15/15 - 0s - loss: 0.0050 - 36ms/epoch - 2ms/step
# Epoch 42/50
# 15/15 - 0s - loss: 0.0050 - 34ms/epoch - 2ms/step
# Epoch 43/50
# 15/15 - 0s - loss: 0.0050 - 34ms/epoch - 2ms/step
# Epoch 44/50
# 15/15 - 0s - loss: 0.0049 - 34ms/epoch - 2ms/step
# Epoch 45/50
# 15/15 - 0s - loss: 0.0049 - 32ms/epoch - 2ms/step
# Epoch 46/50
# 15/15 - 0s - loss: 0.0049 - 33ms/epoch - 2ms/step
# Epoch 47/50
# 15/15 - 0s - loss: 0.0048 - 32ms/epoch - 2ms/step
# Epoch 48/50
# 15/15 - 0s - loss: 0.0048 - 33ms/epoch - 2ms/step
# Epoch 49/50
# 15/15 - 0s - loss: 0.0047 - 33ms/epoch - 2ms/step
# Epoch 50/50
# 15/15 - 0s - loss: 0.0047 - 31ms/epoch - 2ms/step
# 5/5 - 0s - loss: 0.0230 - 123ms/epoch - 25ms/step
# [CV] END ............dropout=0.001, l1_reg=1e-05, n_units=14; total time=   2.3s
# Epoch 1/50
# 20/20 - 0s - loss: 4.1695 - 439ms/epoch - 22ms/step
# Epoch 2/50
# 20/20 - 0s - loss: 2.9883 - 41ms/epoch - 2ms/step
# Epoch 3/50
# 20/20 - 0s - loss: 1.8844 - 41ms/epoch - 2ms/step
# Epoch 4/50
# 20/20 - 0s - loss: 0.8769 - 41ms/epoch - 2ms/step
# Epoch 5/50
# 20/20 - 0s - loss: 0
# Epoch 9/50
# 25/25 - 0s - loss: 0.0026 - 46ms/epoch - 2ms/step
# Epoch 10/50
# 25/25 - 0s - loss: 0.0025 - 47ms/epoch - 2ms/step
# Epoch 11/50
# 25/25 - 0s - loss: 0.0027 - 49ms/epoch - 2ms/step
# Epoch 12/50
# 25/25 - 0s - loss: 0.0026 - 55ms/epoch - 2ms/step
# Epoch 13/50
# 25/25 - 0s - loss: 0.0021 - 45ms/epoch - 2ms/step
# Epoch 14/50
# 25/25 - 0s - loss: 0.0022 - 46ms/epoch - 2ms/step
# Epoch 15/50
# 25/25 - 0s - loss: 0.0020 - 49ms/epoch - 2ms/step
# Epoch 16/50
# 25/25 - 0s - loss: 0.0025 - 45ms/epoch - 2ms/step
# Epoch 17/50
# 25/25 - 0s - loss: 0.0025 - 47ms/epoch - 2ms/step
# Epoch 18/50
# 25/25 - 0s - loss: 0.0023 - 49ms/epoch - 2ms/step
# Epoch 19/50
# 25/25 - 0s - loss: 0.0020 - 47ms/epoch - 2ms/step
# Epoch 20/50
# 25/25 - 0s - loss: 0.0024 - 50ms/epoch - 2ms/step
# Epoch 21/50
# 25/25 - 0s - loss: 0.0021 - 49ms/epoch - 2ms/step
# Epoch 22/50
# 25/25 - 0s - loss: 0.0019 - 51ms/epoch - 2ms/step
# Epoch 23/50
# 25/25 - 0s - loss: 0.0022 - 46ms/epoch - 2ms/step
# Epoch 24/50
# 25/25 - 0s - loss: 0.0022 - 49ms/epoch - 2ms/step
# Epoch 25/50
# 25/25 - 0s - loss: 0.0019 - 46ms/epoch - 2ms/step
# Epoch 26/50
# 25/25 - 0s - loss: 0.0020 - 49ms/epoch - 2ms/step
# Epoch 27/50
# 25/25 - 0s - loss: 0.0020 - 44ms/epoch - 2ms/step
# Epoch 28/50
# 25/25 - 0s - loss: 0.0019 - 49ms/epoch - 2ms/step
# Epoch 29/50
# 25/25 - 0s - loss: 0.0017 - 49ms/epoch - 2ms/step
# Epoch 30/50
# 25/25 - 0s - loss: 0.0019 - 49ms/epoch - 2ms/step
# Epoch 31/50
# 25/25 - 0s - loss: 0.0017 - 46ms/epoch - 2ms/step
# Epoch 32/50
# 25/25 - 0s - loss: 0.0017 - 48ms/epoch - 2ms/step
# Epoch 33/50
# 25/25 - 0s - loss: 0.0018 - 46ms/epoch - 2ms/step
# Epoch 34/50
# 25/25 - 0s - loss: 0.0020 - 47ms/epoch - 2ms/step
# Epoch 35/50
# 25/25 - 0s - loss: 0.0020 - 47ms/epoch - 2ms/step
# Epoch 36/50
# 25/25 - 0s - loss: 0.0016 - 47ms/epoch - 2ms/step
# Epoch 37/50
# 25/25 - 0s - loss: 0.0019 - 50ms/epoch - 2ms/step
# Epoch 38/50
# 25/25 - 0s - loss: 0.0017 - 54ms/epoch - 2ms/step
# Epoch 39/50
# 25/25 - 0s - loss: 0.0018 - 49ms/epoch - 2ms/step
# Epoch 40/50
# 25/25 - 0s - loss: 0.0019 - 48ms/epoch - 2ms/step
# Epoch 41/50
# Epoch 7/50
# 15/15 - 0s - loss: 0.0363 - 31ms/epoch - 2ms/step
# Epoch 8/50
# 15/15 - 0s - loss: 0.0041 - 32ms/epoch - 2ms/step
# Epoch 9/50
# 15/15 - 0s - loss: 0.0011 - 29ms/epoch - 2ms/step
# Epoch 10/50
# 15/15 - 0s - loss: 0.0017 - 31ms/epoch - 2ms/step
# Epoch 11/50
# 15/15 - 0s - loss: 0.0011 - 31ms/epoch - 2ms/step
# Epoch 12/50
# 15/15 - 0s - loss: 0.0013 - 29ms/epoch - 2ms/step
# Epoch 13/50
# 15/15 - 0s - loss: 0.0014 - 28ms/epoch - 2ms/step
# Epoch 14/50
# 15/15 - 0s - loss: 0.0011 - 34ms/epoch - 2ms/step
# Epoch 15/50
# 15/15 - 0s - loss: 9.7920e-04 - 34ms/epoch - 2ms/step
# Epoch 16/50
# 15/15 - 0s - loss: 0.0012 - 29ms/epoch - 2ms/step
# Epoch 17/50
# 15/15 - 0s - loss: 0.0010 - 30ms/epoch - 2ms/step
# Epoch 18/50
# 15/15 - 0s - loss: 0.0013 - 32ms/epoch - 2ms/step
# Epoch 19/50
# 15/15 - 0s - loss: 0.0013 - 30ms/epoch - 2ms/step
# Epoch 20/50
# 15/15 - 0s - loss: 0.0015 - 30ms/epoch - 2ms/step
# Epoch 21/50
# 15/15 - 0s - loss: 9.6199e-04 - 36ms/epoch - 2ms/step
# Epoch 22/50
# 15/15 - 0s - loss: 8.8177e-04 - 33ms/epoch - 2ms/step
# Epoch 23/50
# 15/15 - 0s - loss: 0.0013 - 33ms/epoch - 2ms/step
# Epoch 24/50
# 15/15 - 0s - loss: 0.0015 - 31ms/epoch - 2ms/step
# Epoch 25/50
# 15/15 - 0s - loss: 9.3055e-04 - 31ms/epoch - 2ms/step
# Epoch 26/50
# 15/15 - 0s - loss: 0.0012 - 29ms/epoch - 2ms/step
# Epoch 27/50
# 15/15 - 0s - loss: 0.0012 - 29ms/epoch - 2ms/step
# Epoch 28/50
# 15/15 - 0s - loss: 0.0014 - 31ms/epoch - 2ms/step
# Epoch 29/50
# 15/15 - 0s - loss: 0.0012 - 31ms/epoch - 2ms/step
# Epoch 30/50
# 15/15 - 0s - loss: 9.5322e-04 - 32ms/epoch - 2ms/step
# Epoch 31/50
# 15/15 - 0s - loss: 0.0010 - 31ms/epoch - 2ms/step
# Epoch 32/50
# 15/15 - 0s - loss: 0.0013 - 32ms/epoch - 2ms/step
# Epoch 33/50
# 15/15 - 0s - loss: 0.0011 - 32ms/epoch - 2ms/step
# Epoch 34/50
# 15/15 - 0s - loss: 0.0013 - 31ms/epoch - 2ms/step
# Epoch 35/50
# 15/15 - 0s - loss: 0.0012 - 33ms/epoch - 2ms/step
# Epoch 36/50
# 15/15 - 0s - loss: 0.0012 - 29ms/epoch - 2ms/step
# Epoch 37/50
# 15/15 - 0s - loss: 0.0013 - 30ms/epoch - 2ms/step
# Epoch 38/50
# 15/15 - 0s - loss: 0.0012 - 35ms/epoch - 2ms/step
ms/step
# Epoch 42/50
# 20/20 - 0s - loss: 6.8770e-04 - 46ms/epoch - 2ms/step
# Epoch 43/50
# 20/20 - 0s - loss: 6.7011e-04 - 43ms/epoch - 2ms/step
# Epoch 44/50
# 20/20 - 0s - loss: 7.5657e-04 - 39ms/epoch - 2ms/step
# Epoch 45/50
# 20/20 - 0s - loss: 6.6073e-04 - 38ms/epoch - 2ms/step
# Epoch 46/50
# 20/20 - 0s - loss: 5.8863e-04 - 41ms/epoch - 2ms/step
# Epoch 47/50
# 20/20 - 0s - loss: 5.5620e-04 - 39ms/epoch - 2ms/step
# Epoch 48/50
# 20/20 - 0s - loss: 6.2095e-04 - 37ms/epoch - 2ms/step
# Epoch 49/50
# 20/20 - 0s - loss: 6.1932e-04 - 39ms/epoch - 2ms/step
# Epoch 50/50
# 20/20 - 0s - loss: 5.8453e-04 - 50ms/epoch - 2ms/step
# 5/5 - 0s - loss: 2.2488e-04 - 124ms/epoch - 25ms/step
# [CV] END ............dropout=0.001, l1_reg=1e-05, n_units=16; total time=   2.8s
# Epoch 1/50
# 25/25 - 0s - loss: 1.4290 - 443ms/epoch - 18ms/step
# Epoch 2/50
# 25/25 - 0s - loss: 0.4514 - 49ms/epoch - 2ms/step
# Epoch 3/50
# 25/25 - 0s - loss: 0.0569 - 48ms/epoch - 2ms/step
# Epoch 4/50
# 25/25 - 0s - loss: 0.0016 - 49ms/epoch - 2ms/step
# Epoch 5/50
# 25/25 - 0s - loss: 0.0011 - 50ms/epoch - 2ms/step
# Epoch 6/50
# 25/25 - 0s - loss: 9.8075e-04 - 48ms/epoch - 2ms/step
# Epoch 7/50
# 25/25 - 0s - loss: 0.0010 - 48ms/epoch - 2ms/step
# Epoch 8/50
# 25/25 - 0s - loss: 9.8508e-04 - 48ms/epoch - 2ms/step
# Epoch 9/50
# 25/25 - 0s - loss: 8.9259e-04 - 52ms/epoch - 2ms/step
# Epoch 10/50
# 25/25 - 0s - loss: 0.0010 - 47ms/epoch - 2ms/step
# Epoch 11/50
# 25/25 - 0s - loss: 8.7072e-04 - 50ms/epoch - 2ms/step
# Epoch 12/50
# 25/25 - 0s - loss: 8.5768e-04 - 51ms/epoch - 2ms/step
# Epoch 13/50
# 25/25 - 0s - loss: 8.5717e-04 - 49ms/epoch - 2ms/step
# Epoch 14/50
# 25/25 - 0s - loss: 9.1339e-04 - 48ms/epoch - 2ms/step
# Epoch 15/50
# 25/25 - 0s - loss: 7.4506e-04 - 48ms/epoch - 2ms/step
# Epoch 16/50
# 25/25 - 0s - loss: 0.0010 - 45ms/epoch - 2ms/step
# Epoch 17/50
# 25/25 - 0s - loss: 7.8902e-04 - 47ms/epoch - 2ms/step
# Epoch 18/50
# 25/25 - 0s - loss: 7.9341e-04 - 49ms/epoch - 2ms/step
# Epoch 19/50
# 25/25 - 0s - loss: 8.2528e-04 - 47ms/epoch - 2ms/step
# Epoch 20/50
# 25/25 - 0s - loss: 9.1564e-04 - 46ms/epoch - 2ms/step
# Epoch 21/50
# 25/25 - 0s - loss: 0.0011 - 47ms/epoch - 2ms/step
# Epoch 22/50
# 25/25 - 0s - loss: 8.9417e-04 - 47ms/epoch - 2ms/step
# Epoch 23/50
# 25/25 - 0s - loss: 9.6013e-04 - 47ms/epoch - 2ms/step
# Epoch 24/50
# 25/25 - 0s - loss: 7.4006e-04 - 48ms/epoch - 2ms/step
# Epoch 25/50
# 25/25 - 0s - loss: 7.9785e-04 - 47ms/epoch - 2ms/step
# Epoch 26/50
# 25/25 - 0s - loss: 8.1884e-04 - 46ms/epoch - 2ms/step
# Epoch 27/50
# 25/25 - 0s - loss: 8.8986e-04 - 45ms/epoch - 2ms/step
# Epoch 28/50
# 25/25 - 0s - loss: 8.4771e-04 - 49ms/epoch - 2ms/step
# Epoch 29/50
# 25/25 - 0s - loss: 9.2302e-04 - 53ms/epoch - 2ms/step
# Epoch 30/50
# 25/25 - 0s - loss: 8.1334e-04 - 46ms/epoch - 2ms/step
# Epoch 31/50
# 25/25 - 0s - loss: 8.3604e-04 - 46ms/epoch - 2ms/step
# Epoch 32/50
# 25/25 - 0s - loss: 8.3333e-04 - 46ms/epoch - 2ms/step
# Epoch 33/50
# 25/25 - 0s - loss: 8.4412e-04 - 47ms/epoch - 2ms/step
# Epoch 34/50
# 25/25 - 0s - loss: 8.5723e-04 - 45ms/epoch - 2ms/step
# Epoch 35/50
# 25/25 - 0s - loss: 7.7441e-04 - 48ms/epoch - 2ms/step
# Epoch 36/50
# 25/25 - 0s - loss: 8.5144e-04 - 46ms/epoch - 2ms/step
# Epoch 37/50
# 25/25 - 0s - loss: 8.0828e-04 - 48ms/epoch - 2ms/step
# Epoch 38/50
# 25/25 - 0s - loss: 8.1674e-04 - 44ms/epoch - 2ms/step
# Epoch 39/50
# 25/25 - 0s - loss: 8.9628e-04 - 47ms/epoch - 2ms/step
# Epoch 40/50
# 25/25 - 0s - loss: 7.9005e-04 - 48ms/epoch - 2ms/step
# Epoch 41/50
# 25/25 - 0s - loss: 8.6606e-04 - 47ms/epoch - 2ms/step
# Epoch 42/50
# 25/25 - 0s - loss: 7.7662e-04 - 46ms/epoch - 2ms/step
# Epoch 43/50
# 25/25 - 0s - loss: 8.5978e-04 - 48ms/epoch - 2ms/step
# Epoch 44/50
# 25/25 - 0s - loss: 9.8876e-04 - 48ms/epoch - 2ms/step
# Epoch 45/50
# 25/25 - 0s - loss: 8.4699e-04 - 47ms/epoch - 2ms/step
# Epoch 46/50
# 25/25 - 0s - loss: 8.4649e-04 - 45ms/epoch - 2ms/step
# Epoch 47/50
# 25/25 - 0s - loss: 7.6979e-04 - 49ms/epoch - 2ms/step
# Epoch 48/50
# 25/25 - 0s - loss: 7.8570e-04 - 47ms/epoch - 2ms/step
# Epoch 49/50
# 25/25 - 0s - loss: 8.2807e-04 - 45ms/epoch - 2ms/step
# Epoch 50/50
# 25/25 - 0s - loss: 7.7994e-04 - 48ms/epoch - 2ms/step
# 5/5 - 0s - loss: 5.4548e-04 - 123ms/epoch - 25ms/step
# [CV] END ............dropout=0.001, l1_reg=1e-05, n_units=16; total time=   3.1s
# Epoch 1/50
# 5/5 - 0s - loss: 0.0060 - 411ms/epoch - 82ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.0014 - 15ms/epoch - 3ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.0022 - 15ms/epoch - 3ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 7.5194e-04 - 14ms/epoch - 3ms/step
# Epoch 5/50
# 5/5 - 0s - loss:
# 15/15 - 0s - loss: 8.9900e-04 - 30ms/epoch - 2ms/step
# Epoch 17/50
# 15/15 - 0s - loss: 9.3623e-04 - 29ms/epoch - 2ms/step
# Epoch 18/50
# 15/15 - 0s - loss: 6.9400e-04 - 29ms/epoch - 2ms/step
# Epoch 19/50
# 15/15 - 0s - loss: 9.1685e-04 - 30ms/epoch - 2ms/step
# Epoch 20/50
# 15/15 - 0s - loss: 9.6535e-04 - 29ms/epoch - 2ms/step
# Epoch 21/50
# 15/15 - 0s - loss: 8.9882e-04 - 32ms/epoch - 2ms/step
# Epoch 22/50
# 15/15 - 0s - loss: 7.7312e-04 - 33ms/epoch - 2ms/step
# Epoch 23/50
# 15/15 - 0s - loss: 8.0942e-04 - 31ms/epoch - 2ms/step
# Epoch 24/50
# 15/15 - 0s - loss: 9.1775e-04 - 30ms/epoch - 2ms/step
# Epoch 25/50
# 15/15 - 0s - loss: 9.4468e-04 - 29ms/epoch - 2ms/step
# Epoch 26/50
# 15/15 - 0s - loss: 7.8558e-04 - 34ms/epoch - 2ms/step
# Epoch 27/50
# 15/15 - 0s - loss: 8.3811e-04 - 30ms/epoch - 2ms/step
# Epoch 28/50
# 15/15 - 0s - loss: 8.7518e-04 - 29ms/epoch - 2ms/step
# Epoch 29/50
# 15/15 - 0s - loss: 0.0011 - 28ms/epoch - 2ms/step
# Epoch 30/50
# 15/15 - 0s - loss: 9.6584e-04 - 30ms/epoch - 2ms/step
# Epoch 31/50
# 15/15 - 0s - loss: 8.6777e-04 - 30ms/epoch - 2ms/step
# Epoch 32/50
# 15/15 - 0s - loss: 0.0010 - 30ms/epoch - 2ms/step
# Epoch 33/50
# 15/15 - 0s - loss: 8.3784e-04 - 33ms/epoch - 2ms/step
# Epoch 34/50
# 15/15 - 0s - loss: 8.3419e-04 - 34ms/epoch - 2ms/step
# Epoch 35/50
# 15/15 - 0s - loss: 9.0622e-04 - 29ms/epoch - 2ms/step
# Epoch 36/50
# 15/15 - 0s - loss: 9.7175e-04 - 28ms/epoch - 2ms/step
# Epoch 37/50
# 15/15 - 0s - loss: 7.8617e-04 - 31ms/epoch - 2ms/step
# Epoch 38/50
# 15/15 - 0s - loss: 7.5070e-04 - 31ms/epoch - 2ms/step
# Epoch 39/50
# 15/15 - 0s - loss: 9.3684e-04 - 32ms/epoch - 2ms/step
# Epoch 40/50
# 15/15 - 0s - loss: 9.3334e-04 - 31ms/epoch - 2ms/step
# Epoch 41/50
# 15/15 - 0s - loss: 7.7391e-04 - 31ms/epoch - 2ms/step
# Epoch 42/50
# 15/15 - 0s - loss: 9.1721e-04 - 29ms/epoch - 2ms/step
# Epoch 43/50
# 15/15 - 0s - loss: 8.5715e-04 - 32ms/epoch - 2ms/step
# Epoch 44/50
# 15/15 - 0s - loss: 0.0010 - 33ms/epoch - 2ms/step
# Epoch 45/50
# 15/15 - 0s - loss: 6.7017e-04 - 31ms/epoch - 2ms/step
# Epoch 46/50
# 15/15 - 0s - loss: 8.3651e-04 - 29ms/epoch - 2ms/step
# Epoch 47/50
# 15/15 - 0s - loss: 8.1591e-04 - 30ms/epoch - 2ms/step
# Epoch 48/50
# 15/15 - 0s - loss: 8.8273e-04 - 29ms/epoch - 2ms/step
# Epoch 49/50
# 15/15 - 0s - loss: 8.2910e-04 - 31ms/epoch - 2ms/step
# Epoch 50/50
# 15/15 - 0s - loss: 9.2012e-04 - 31ms/epoch - 2ms/step
# 5/5 - 0s - loss: 0.0017 - 117ms/epoch - 23ms/step
# [CV] END ............dropout=0.001, l1_reg=1e-05, n_units=18; total time=   2.3s
# Epoch 1/50
# 20/20 - 0s - loss: 0.9340 - 443ms/epoch - 22ms/step
# Epoch 2/50
# 20/20 - 0s - loss: 0.3287 - 40ms/epoch - 2ms/step
# Epoch 3/50
# 20/20 - 0s - loss: 0.0372 - 38ms/epoch - 2ms/step
# Epoch 4/50
# 20/20 - 0s - loss: 0.0048 - 41ms/epoch - 2ms/step
# Epoch 5/50
# 20/20 - 0s - loss: 0.0026 - 39ms/epoch - 2ms/step
# Epoch 6/50
# 20/20 - 0s - loss: 0.0024 - 41ms/epoch - 2ms/step
# Epoch 7/50
# 20/20 - 0s - loss: 0.0023 - 40ms/epoch - 2ms/step
# Epoch 8/50
# 20/20 - 0s - loss: 0.0022 - 39ms/epoch - 2ms/step
# Epoch 9/50
# 20/20 - 0s - loss: 0.0022 - 37ms/epoch - 2ms/step
# Epoch 10/50
# 20/20 - 0s - loss: 0.0022 - 39ms/epoch - 2ms/step
# Epoch 11/50
# 20/20 - 0s - loss: 0.0022 - 38ms/epoch - 2ms/step
# Epoch 12/50
# 20/20 - 0s - loss: 0.0021 - 40ms/epoch - 2ms/step
# Epoch 13/50
# 20/20 - 0s - loss: 0.0021 - 46ms/epoch - 2ms/step
# Epoch 14/50
# 20/20 - 0s - loss: 0.0022 - 43ms/epoch - 2ms/step
# Epoch 15/50
# 20/20 - 0s - loss: 0.0021 - 39ms/epoch - 2ms/step
# Epoch 16/50
# 20/20 - 0s - loss: 0.0021 - 42ms/epoch - 2ms/step
# Epoch 17/50
# 20/20 - 0s - loss: 0.0020 - 38ms/epoch - 2ms/step
# Epoch 18/50
# 20/20 - 0s - loss: 0.0019 - 41ms/epoch - 2ms/step
# Epoch 19/50
# 20/20 - 0s - loss: 0.0019 - 40ms/epoch - 2ms/step
# Epoch 20/50
# 20/20 - 0s - loss: 0.0019 - 37ms/epoch - 2ms/step
# Epoch 21/50
# 20/20 - 0s - loss: 0.0019 - 45ms/epoch - 2ms/step
# Epoch 22/50
# 20/20 - 0s - loss: 0.0019 - 38ms/epoch - 2ms/step
# Epoch 23/50
# 20/20 - 0s - loss: 0.0018 - 39ms/epoch - 2ms/step
# Epoch 24/50
# 20/20 - 0s - loss: 0.0018 - 39ms/epoch - 2ms/step
# Epoch 25/50
# 20/20 - 0s - loss: 0.0018 - 41ms/epoch - 2ms/step
# Epoch 26/50
# 20/20 - 0s - loss: 0.0017 - 41ms/epoch - 2ms/step
# Epoch 27/50
# 20/20 - 0s - loss: 0.0017 - 36ms/epoch - 2ms/step
# Epoch 28/50
# 20/20 - 0s - loss: 0.0017 - 39ms/epoch - 2ms/step
# Epoch 29/50
# 20/20 - 0s - loss: 0.0017 - 39ms/epoch - 2ms/step
# Epoch 30/50
# 20/20 - 0s - loss: 0.0016 - 38ms/epoch - 2ms/step
# Epoch 31/50
# 20/20 - 0s - loss: 0.0015 - 42ms/epoch - 2ms/step
# Epoch 32/50
# 20/20 - 0s - loss: 0.0016 - 37ms/epoch - 2ms/step
# Epoch 33/50
# 20/20 - 0s - loss: 0.0015 - 38ms/epoch - 2ms/step
# Epoch 34/50
# 20/20 - 0s - loss: 0.0014 - 43ms/epoch - 2ms/step
# Epoch 35/50
# 20/20 - 0s - loss: 0.0014 - 43ms/epoch - 2ms/step
# Epoch 36/50
# 20/20 - 0s - loss: 0.0014 - 44ms/epoch - 2ms/step
# Epoch 37/50
# 20/20 - 0s - loss: 0.0014 - 45ms/epoch - 2ms/step
# Epoch 38/50
# 20/20 - 0s - loss: 0.0013 - 41ms/epoch - 2ms/step
# Epoch 39/50
# 20/20 - 0s - loss: 0.0014 - 41ms/epoch - 2ms/step
# Epoch 40/50
# 20/20 - 0s - loss: 0.0013 - 39ms/epoch - 2ms/step
# Epoch 41/50
# 20/20 - 0s - loss: 0.0012 - 39ms/epoch - 2ms/step
# Epoch 42/50
# 20/20 - 0s - loss: 0.0013 - 37ms/epoch - 2ms/step
# Epoch 43/50
# 20/20 - 0s - loss: 0.0012 - 40ms/epoch - 2ms/step
# Epoch 44/50
# 20/20 - 0s - loss: 0.0012 - 38ms/epoch - 2ms/step
# Epoch 45/50
# 20/20 - 0s - loss: 0.0012 - 50ms/epoch - 3ms/step
# Epoch 46/50
# 20/20 - 0s - loss: 0.0012 - 38ms/epoch - 2ms/step
# Epoch 47/50
# 20/20 - 0s - loss: 0.0012 - 42ms/epoch - 2ms/step
# Epoch 48/50
# 20/20 - 0s - loss: 0.0012 - 38ms/epoch - 2ms/step
# Epoch 49/50
# 20/20 - 0s - loss: 0.0012 - 39ms/epoch - 2ms/step
# Epoch 50/50
# 20/20 - 0s - loss: 0.0012 - 40ms/epoch - 2ms/step
# 5/5 - 0s - loss: 0.0016 - 115ms/epoch - 23ms/step
# [CV] END ............dropout=0.001, l1_reg=1e-05, n_units=18; total time=   2.7s
# Epoch 1/50
# 25/25 - 0s - loss: 0.0448 - 445ms/epoch - 18ms/step
# Epoch 2/50
# 25/25 - 0s - loss: 0.0059 - 48ms/epoch - 2ms/step
# Epoch 3/50
# 25/25 - 0s - loss: 0.0044 - 54ms/epoch - 2ms/step
# Epoch 4/50
# 25/25 - 0s - loss: 0.0042 - 51ms/epoch - 2ms/step
# Epoch 5/50
# 25/25 - 0s - loss: 0.0041 - 52ms/epoch - 2ms/step
# Epoch 6/50
# 25/25 - 0s - loss: 0.0039 - 46ms/epoch - 2ms/step
# Epoch 7/50
# 25/25 - 0s - loss: 0.0037 - 48ms/epoch - 2ms/step
# Epoch 8/50
# 25/25 - 0s - loss: 0.0035 - 49ms/epoch - 2ms/step
# Epoch 9/50
# 25/25 - 0s - loss: 0.0033 - 49ms/epoch - 2ms/step
# Epoch 10/50
# 25/25 - 0s - loss: 0.0031 - 49ms/epoch - 2ms/step
# Epoch 11/50
# 25/25 - 0s - loss: 0.0028 - 49ms/epoch - 2ms/step
# Epoch 12/50
# 25/25 - 0s - loss: 0.0026 - 47ms/epoch - 2ms/step
# Epoch 13/50
# 25/25 - 0s - loss: 0.0024 - 46ms/epoch - 2ms/step
# Epoch 14/50
# 25/25 - 0s - loss: 0.0021 - 49ms/epoch - 2ms/step
# Epoch 15/50
# 25/25 - 0s - loss: 0.0016 - 47ms/epoch - 2ms/step
# Epoch 16/50
# 25/25 - 0s - loss: 0.0014 - 49ms/epoch - 2ms/step
# Epoch 17/50
# 25/25 - 0s - loss: 0.0011 - 49ms/epoch - 2ms/step
# Epoch 18/50
# 25/25 - 0s - loss: 0.0011 - 46ms/epoch - 2ms/step
# Epoch 19/50
# 25/25 - 0s - loss: 9.6801e-04 - 50ms/epoch - 2ms/step
# Epoch 20/50
# 25/25 - 0s - loss: 8.9863e-04 - 47ms/epoch - 2ms/step
# Epoch 21/50
# 25/25 - 0s - loss: 8.6813e-04 - 50ms/epoch - 2ms/step
# Epoch 22/50
# 25/25 - 0s - loss: 9.0218e-04 - 47ms/epoch - 2ms/step
# Epoch 23/50
# 25/25 - 0s - loss: 8.8126e-04 - 53ms/epoch - 2ms/step
# Epoch 24/50
# 25/25 - 0s - loss: 9.0716e-04 - 46ms/epoch - 2ms/step
# Epoch 25/50
# 25/25 - 0s - loss: 7.0835e-04 - 48ms/epoch - 2ms/step
# Epoch 26/50
# 25/25 - 0s - loss: 7.4743e-04 - 49ms/epoch - 2ms/step
# Epoch 27/50
# 25/25 - 0s - loss: 8.8775e-04 - 49ms/epoch - 2ms/step
# Epoch 28/50
# 25/25 - 0s - loss: 7.5756e-04 - 48ms/epoch - 2ms/step
# Epoch 29/50
# 25/25 - 0s - loss: 8.5701e-04 - 51ms/epoch - 2ms/step
# Epoch 30/50
# 25/25 - 0s - loss: 7.9729e-04 - 48ms/epoch - 2ms/step
# Epoch 31/50
# 25/25 - 0s - loss: 9.1041e-04 - 48ms/epoch - 2ms/step
# Epoch 32/50
# 25/25 - 0s - loss: 7.7835e-04 - 49ms/epoch - 2ms/step
# Epoch 33/50
# 25/25 - 0s - loss: 7.9452e-04 - 50ms/epoch - 2ms/step
# Epoch 34/50
# 25/25 - 0s - loss: 8.7930e-04 - 50ms/epoch - 2ms/step
# Epoch 35/50
# 25/25 - 0s - loss: 7.2872e-04 - 52ms/epoch - 2ms/step
# Epoch 36/50
# 25/25 - 0s - loss: 7.3270e-04 - 47ms/epoch - 2ms/step
# Epoch 37/50
# 25/25 - 0s - loss: 8.1051e-04 - 45ms/epoch - 2ms/step
# Epoch 38/50
# 25/25 - 0s - loss: 7.0436e-04 - 48ms/epoch - 2ms/step
# Epoch 39/50
# 25/25 - 0s - loss: 8.4194e-04 - 46ms/epoch - 2ms/step
ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 6.6332e-04 - 14ms/epoch - 3ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 5.7041e-04 - 12ms/epoch - 2ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 8.1652e-04 - 15ms/epoch - 3ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 7.2204e-04 - 12ms/epoch - 2ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 5.6383e-04 - 15ms/epoch - 3ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 5.7447e-04 - 13ms/epoch - 3ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 5.7751e-04 - 14ms/epoch - 3ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 6.5152e-04 - 12ms/epoch - 2ms/step
# 5/5 - 0s - loss: 0.0016 - 115ms/epoch - 23ms/step
# [CV] END ............dropout=0.001, l1_reg=1e-05, n_units=20; total time=   1.4s
# Epoch 1/50
# 10/10 - 1s - loss: 0.7400 - 751ms/epoch - 75ms/step
# Epoch 2/50
# 10/10 - 0s - loss: 0.4396 - 25ms/epoch - 2ms/step
# Epoch 3/50
# 10/10 - 0s - loss: 0.2299 - 23ms/epoch - 2ms/step
# Epoch 4/50
# 10/10 - 0s - loss: 0.0972 - 22ms/epoch - 2ms/step
# Epoch 5/50
# 10/10 - 0s - loss: 0.0279 - 24ms/epoch - 2ms/step
# Epoch 6/50
# 10/10 - 0s - loss: 0.0049 - 23ms/epoch - 2ms/step
# Epoch 7/50
# 10/10 - 0s - loss: 0.0027 - 22ms/epoch - 2ms/step
# Epoch 8/50
# 10/10 - 0s - loss: 0.0033 - 25ms/epoch - 2ms/step
# Epoch 9/50
# 10/10 - 0s - loss: 0.0027 - 24ms/epoch - 2ms/step
# Epoch 10/50
# 10/10 - 0s - loss: 0.0024 - 23ms/epoch - 2ms/step
# Epoch 11/50
# 10/10 - 0s - loss: 0.0023 - 23ms/epoch - 2ms/step
# Epoch 12/50
# 10/10 - 0s - loss: 0.0023 - 29ms/epoch - 3ms/step
# Epoch 13/50
# 10/10 - 0s - loss: 0.0022 - 22ms/epoch - 2ms/step
# Epoch 14/50
# 10/10 - 0s - loss: 0.0023 - 23ms/epoch - 2ms/step
# Epoch 15/50
# 10/10 - 0s - loss: 0.0022 - 22ms/epoch - 2ms/step
# Epoch 16/50
# 10/10 - 0s - loss: 0.0023 - 22ms/epoch - 2ms/step
# Epoch 17/50
# 10/10 - 0s - loss: 0.0023 - 21ms/epoch - 2ms/step
# Epoch 18/50
# 10/10 - 0s - loss: 0.0023 - 22ms/epoch - 2ms/step
# Epoch 19/50
# 10/10 - 0s - loss: 0.0023 - 21ms/epoch - 2ms/step
# Epoch 20/50
# 10/10 - 0s - loss: 0.0022 - 22ms/epoch - 2ms/step
# Epoch 21/50
# 10/10 - 0s - loss: 0.0023 - 24ms/epoch - 2ms/step
# Epoch 22/50
# 10/10 - 0s - loss: 0.0022 - 23ms/epoch - 2ms/step
# Epoch 23/50
# 10/10 - 0s - loss: 0.0024 - 21ms/epoch - 2ms/step
# Epoch 24/50
# 10/10 - 0s - loss: 0.0024 - 22ms/epoch - 2ms/step
# Epoch 25/50
# 10/10 - 0s - loss: 0.0022 - 22ms/epoch - 2ms/step
# Epoch 26/50
# 10/10 - 0s - loss: 0.0023 - 22ms/epoch - 2ms/step
# Epoch 27/50
# 10/10 - 0s - loss: 0.0022 - 24ms/epoch - 2ms/step
# Epoch 28/50
# 10/10 - 0s - loss: 0.0021 - 22ms/epoch - 2ms/step
# Epoch 29/50
# 10/10 - 0s - loss: 0.0022 - 21ms/epoch - 2ms/step
# Epoch 30/50
# 10/10 - 0s - loss: 0.0021 - 24ms/epoch - 2ms/step
# Epoch 31/50
# 10/10 - 0s - loss: 0.0021 - 22ms/epoch - 2ms/step
# Epoch 32/50
# 10/10 - 0s - loss: 0.0023 - 22ms/epoch - 2ms/step
# Epoch 33/50
# 10/10 - 0s - loss: 0.0022 - 22ms/epoch - 2ms/step
# Epoch 34/50
# 10/10 - 0s - loss: 0.0023 - 23ms/epoch - 2ms/step
# Epoch 35/50
# 10/10 - 0s - loss: 0.0020 - 22ms/epoch - 2ms/step
# Epoch 36/50
# 10/10 - 0s - loss: 0.0021 - 23ms/epoch - 2ms/step
# Epoch 37/50
# 10/10 - 0s - loss: 0.0021 - 23ms/epoch - 2ms/step
# Epoch 38/50
# 10/10 - 0s - loss: 0.0021 - 22ms/epoch - 2ms/step
# Epoch 39/50
# 10/10 - 0s - loss: 0.0022 - 22ms/epoch - 2ms/step
# Epoch 40/50
# 10/10 - 0s - loss: 0.0022 - 23ms/epoch - 2ms/step
# Epoch 41/50
# 10/10 - 0s - loss: 0.0021 - 20ms/epoch - 2ms/step
# Epoch 42/50
# 10/10 - 0s - loss: 0.0022 - 21ms/epoch - 2ms/step
# Epoch 43/50
# 10/10 - 0s - loss: 0.0020 - 24ms/epoch - 2ms/step
# Epoch 44/50
# 10/10 - 0s - loss: 0.0021 - 22ms/epoch - 2ms/step
# Epoch 45/50
# 10/10 - 0s - loss: 0.0022 - 21ms/epoch - 2ms/step
# Epoch 46/50
# 10/10 - 0s - loss: 0.0021 - 20ms/epoch - 2ms/step
# Epoch 47/50
# 10/10 - 0s - loss: 0.0020 - 23ms/epoch - 2ms/step
# Epoch 48/50
# 10/10 - 0s - loss: 0.0020 - 21ms/epoch - 2ms/step
# Epoch 49/50
# 10/10 - 0s - loss: 0.0020 - 22ms/epoch - 2ms/step
# Epoch 50/50
# 10/10 - 0s - loss: 0.0020 - 23ms/epoch - 2ms/step
# 5/5 - 0s - loss: 0.0040 - 126ms/epoch - 25ms/step
# [CV] END ............dropout=0.001, l1_reg=1e-05, n_units=20; total time=   2.2s
# Epoch 1/50
# 15/15 - 0s - loss: 4.0518 - 441ms/epoch - 29ms/step
# Epoch 2/50
# 15/15 - 0s - loss: 2.9141 - 33ms/epoch - 2ms/step
# Epoch 3/50
# 15/15 - 0s - loss: 1.9514 - 33ms/epoch - 2ms/step
# Epoch 4/50
# 15/15 - 0s - loss: 1.0906 - 33ms/epoch - 2ms/step
# Epoch 5/50
# 15/15 - 0s - loss: 0.4032 - 34ms/epoch - 2ms/step
# Epoch 6/50
# 15/15 - 0s - loss: 0.0514 - 33ms/epoch - 2ms/step
# Epoch 7/50
# 15/15 - 0s - loss: 0.0055 - 33ms/epoch - 2ms/step
# Epoch 8/50
# 15/15 - 0s - loss: 0.0041 - 31ms/epoch - 2ms/step
# Epoch 9/50
# 15/15 - 0s - loss: 7.9565e-04 - 31ms/epoch - 2ms/step
# Epoch 10/50
# 15/15 - 0s - loss: 7.9038e-04 - 31ms/epoch - 2ms/step
# Epoch 11/50
# 15/15 - 0s - loss: 6.9213e-04 - 31ms/epoch - 2ms/step
# Epoch 12/50
# 15/15 - 0s - loss: 8.5664e-04 - 32ms/epoch - 2ms/step
# Epoch 13/50
# ...
# Epoch 42/50
# 20/20 - 0s - loss: 0.0014 - 43ms/epoch - 2ms/step
# Epoch 43/50
# 20/20 - 0s - loss: 0.0015 - 39ms/epoch - 2ms/step
# Epoch 44/50
# 20/20 - 0s - loss: 0.0013 - 38ms/epoch - 2ms/step
# Epoch 45/50
# 20/20 - 0s - loss: 0.0014 - 35ms/epoch - 2ms/step
# Epoch 46/50
# 20/20 - 0s - loss: 0.0014 - 38ms/epoch - 2ms/step
# Epoch 47/50
# 20/20 - 0s - loss: 0.0014 - 38ms/epoch - 2ms/step
# Epoch 48/50
# 20/20 - 0s - loss: 0.0014 - 38ms/epoch - 2ms/step
# Epoch 49/50
# 20/20 - 0s - loss: 0.0012 - 39ms/epoch - 2ms/step
# Epoch 50/50
# 20/20 - 0s - loss: 0.0014 - 37ms/epoch - 2ms/step
# 5/5 - 0s - loss: 0.0014 - 120ms/epoch - 24ms/step
# [CV] END ............dropout=0.001, l1_reg=5e-05, n_units=22; total time=   2.8s
# Epoch 1/50
# 25/25 - 0s - loss: 2.1292 - 467ms/epoch - 19ms/step
# Epoch 2/50
# 25/25 - 0s - loss: 0.8631 - 52ms/epoch - 2ms/step
# Epoch 3/50
# 25/25 - 0s - loss: 0.1255 - 48ms/epoch - 2ms/step
# Epoch 4/50
# 25/25 - 0s - loss: 0.0052 - 48ms/epoch - 2ms/step
# Epoch 5/50
# 25/25 - 0s - loss: 0.0023 - 47ms/epoch - 2ms/step
# Epoch 6/50
# 25/25 - 0s - loss: 0.0021 - 47ms/epoch - 2ms/step
# Epoch 7/50
# 25/25 - 0s - loss: 0.0020 - 50ms/epoch - 2ms/step
# Epoch 8/50
# 25/25 - 0s - loss: 0.0021 - 47ms/epoch - 2ms/step
# Epoch 9/50
# 25/25 - 0s - loss: 0.0020 - 46ms/epoch - 2ms/step
# Epoch 10/50
# 25/25 - 0s - loss: 0.0021 - 46ms/epoch - 2ms/step
# Epoch 11/50
# 25/25 - 0s - loss: 0.0021 - 45ms/epoch - 2ms/step
# Epoch 12/50
# 25/25 - 0s - loss: 0.0019 - 46ms/epoch - 2ms/step
# Epoch 13/50
# 25/25 - 0s - loss: 0.0020 - 47ms/epoch - 2ms/step
# Epoch 14/50
# 25/25 - 0s - loss: 0.0020 - 47ms/epoch - 2ms/step
# Epoch 15/50
# 25/25 - 0s - loss: 0.0020 - 47ms/epoch - 2ms/step
# Epoch 16/50
# 25/25 - 0s - loss: 0.0019 - 48ms/epoch - 2ms/step
# Epoch 17/50
# 25/25 - 0s - loss: 0.0019 - 49ms/epoch - 2ms/step
# Epoch 18/50
# 25/25 - 0s - loss: 0.0019 - 48ms/epoch - 2ms/step
# Epoch 19/50
# 25/25 - 0s - loss: 0.0019 - 45ms/epoch - 2ms/step
# Epoch 20/50
# 25/25 - 0s - loss: 0.0018 - 48ms/epoch - 2ms/step
# Epoch 21/50
# 25/25 - 0s - loss: 0.0019 - 45ms/epoch - 2ms/step
# Epoch 22/50
# 25/25 - 0s - loss: 0.0019 - 46ms/epoch - 2ms/step
# Epoch 23/50
# 25/25 - 0s - loss: 0.0016 - 51ms/epoch - 2ms/step
# Epoch 24/50
# 25/25 - 0s - loss: 0.0017 - 47ms/epoch - 2ms/step
# Epoch 25/50
# 25/25 - 0s - loss: 0.0018 - 48ms/epoch - 2ms/step
# Epoch 26/50
# 25/25 - 0s - loss: 0.0017 - 45ms/epoch - 2ms/step
# Epoch 27/50
# 25/25 - 0s - loss: 0.0016 - 47ms/epoch - 2ms/step
# Epoch 28/50
# 25/25 - 0s - loss: 0.0019 - 49ms/epoch - 2ms/step
# Epoch 29/50
# 25/25 - 0s - loss: 0.0017 - 46ms/epoch - 2ms/step
# Epoch 30/50
# 25/25 - 0s - loss: 0.0017 - 45ms/epoch - 2ms/step
# Epoch 31/50
# 25/25 - 0s - loss: 0.0018 - 48ms/epoch - 2ms/step
# Epoch 32/50
# 25/25 - 0s - loss: 0.0018 - 46ms/epoch - 2ms/step
# Epoch 33/50
# 25/25 - 0s - loss: 0.0016 - 46ms/epoch - 2ms/step
# Epoch 34/50
# 25/25 - 0s - loss: 0.0017 - 46ms/epoch - 2ms/step
# Epoch 35/50
# 25/25 - 0s - loss: 0.0016 - 45ms/epoch - 2ms/step
# Epoch 36/50
# 25/25 - 0s - loss: 0.0015 - 46ms/epoch - 2ms/step
# Epoch 37/50
# 25/25 - 0s - loss: 0.0015 - 45ms/epoch - 2ms/step
# Epoch 38/50
# 25/25 - 0s - loss: 0.0014 - 52ms/epoch - 2ms/step
# Epoch 39/50
# 25/25 - 0s - loss: 0.0016 - 51ms/epoch - 2ms/step
# Epoch 40/50
# 25/25 - 0s - loss: 0.0017 - 46ms/epoch - 2ms/step
# Epoch 41/50
# 25/25 - 0s - loss: 0.0015 - 46ms/epoch - 2ms/step
# Epoch 42/50
# 25/25 - 0s - loss: 0.0016 - 48ms/epoch - 2ms/step
# Epoch 43/50
# 25/25 - 0s - loss: 0.0015 - 47ms/epoch - 2ms/step
# Epoch 44/50
# 25/25 - 0s - loss: 0.0014 - 48ms/epoch - 2ms/step
# Epoch 45/50
# 25/25 - 0s - loss: 0.0016 - 47ms/epoch - 2ms/step
# Epoch 46/50
# 25/25 - 0s - loss: 0.0013 - 49ms/epoch - 2ms/step
# Epoch 47/50
# 25/25 - 0s - loss: 0.0018 - 48ms/epoch - 2ms/step
# Epoch 48/50
# 25/25 - 0s - loss: 0.0013 - 54ms/epoch - 2ms/step
# Epoch 49/50
# 25/25 - 0s - loss: 0.0015 - 47ms/epoch - 2ms/step
# Epoch 50/50
# 25/25 - 0s - loss: 0.0014 - 48ms/epoch - 2ms/step
# 5/5 - 0s - loss: 0.0013 - 428ms/epoch - 86ms/step
# [CV] END ............dropout=0.001, l1_reg=5e-05, n_units=22; total time=   3.5s
# Epoch 1/50
# 30/30 - 0s - loss: 0.0060 - 447ms/epoch - 15ms/step
# Epoch 2/50
# 30/30 - 0s - loss: 0.0047 - 54ms/epoch - 2ms/step
# Epoch 3/50
# 30/30 - 0s - loss: 0.0039 - 60ms/epoch - 2ms/step
# Epoch 4/50
# 30/30 - 0s - loss: 0.0030 - 57ms/epoch - 2ms/step
# Epoch 5/50
# 30/30 - 0s - loss: 0.0017 - 57ms/epoch - 2ms/step
# Epoch 6/50
# 30/30 - 0s - loss: 6.3655e-04 - 58ms/epoch - 2ms/step
# Epoch 7/50
# 30/30 - 0s - loss: 2.0257e-04 - 56ms/epoch - 2ms/step
# Epoch 8/50
# 30/30 - 0s - loss: 1.7753e-04 - 54ms/epoch - 2ms/step
# Epoch 9/50
# 30/30 - 0s - loss: 2.5050e-04 - 59ms/epoch - 2ms/step
# Epoch 10/50
# 30/30 - 0s - loss: 1.3929e-04 - 58ms/epoch - 2ms/step
# Epoch 11/50
# 30/30 - 0s - loss: 1.5747e-04 - 55ms/epoch - 2ms/step
# Epoch 12/50
# 30/30 - 0s - loss: 1.8140e-04 - 55ms/epoch - 2ms/step
# Epoch 13/50
# 30/30 - 0s - loss: 1.3739e-04 - 56ms/epoch - 2ms/step
# Epoch 14/50
# 30/30 - 0s - loss: 1.5114e-04 - 56ms/epoch - 2ms/step
# Epoch 15/50
# 30/30 - 0s - loss: 9.8225e-05 - 55ms/epoch - 2ms/step
# Epoch 16/50
# 30/30 - 0s - loss: 1.3839e-04 - 56ms/epoch - 2ms/step
# Epoch 17/50
# 30/30 - 0s - loss: 1.3858e-04 - 54ms/epoch - 2ms/step
# Epoch 18/50
# 30/30 - 0s - loss: 1.8101e-04 - 53ms/epoch - 2ms/step
# Epoch 19/50
# 30/30 - 0s - loss: 1.4825e-04 - 54ms/epoch - 2ms/step
# Epoch 20/50
# 30/30 - 0s - loss: 7.0852e-05 - 55ms/epoch - 2ms/step
# Epoch 21/50
# 30/30 - 0s - loss: 1.1653e-04 - 61ms/epoch - 2ms/step
# Epoch 22/50
# 30/30 - 0s - loss: 1.9520e-04 - 56ms/epoch - 2ms/step
# Epoch 23/50
# 30/30 - 0s - loss: 1.6958e-04 - 54ms/epoch - 2ms/step
# Epoch 24/50
# 30/30 - 0s - loss: 9.9886e-05 - 55ms/epoch - 2ms/step
# Epoch 25/50
# 30/30 - 0s - loss: 1.5832e-04 - 53ms/epoch - 2ms/step
# Epoch 26/50
# 30/30 - 0s - loss: 1.1598e-04 - 56ms/epoch - 2ms/step
# Epoch 27/50
# 30/30 - 0s - loss: 1.8363e-04 - 60ms/epoch - 2ms/step
# Epoch 28/50
# 30/30 - 0s - loss: 1.7594e-04 - 56ms/epoch - 2ms/step
# Epoch 29/50
# 30/30 - 0s - loss: 1.1707e-04 - 58ms/epoch - 2ms/step
# Epoch 30/50
# 30/30 - 0s - loss: 1.8141e-04 - 55ms/epoch - 2ms/step
# Epoch 31/50
# 30/30 - 0s - loss: 1.6014e-04 - 53ms/epoch - 2ms/step
# Epoch 32/50
# 30/30 - 0s - loss: 1.5932e-04 - 56ms/epoch - 2ms/step
# Epoch 33/50
# 30/30 - 0s - loss: 1.3231e-04 - 58ms/epoch - 2ms/step
# Epoch 34/50
# 30/30 - 0s - loss: 1.3881e-04 - 59ms/epoch - 2ms/step
# Epoch 35/50
# 30/30 - 0s - loss: 2.1498e-04 - 59ms/epoch - 2ms/step
# Epoch 36/50
# 30/30 - 0s - loss: 2.0197e-04 - 54ms/epoch - 2ms/step
# Epoch 37/50
# 30/30 - 0s - loss: 1.3113e-04 - 54ms/epoch - 2ms/step
# Epoch 38/50
# 30/30 - 0s - loss: 1.5781e-04 - 60ms/epoch - 2ms/step
# Epoch 39/50
# 30/30 - 0s - loss: 1.2232e-04 - 58ms/epoch - 2ms/step
# Epoch 40/50
# 30/30 - 0s - loss: 1.5289e-04 - 57ms/epoch - 2ms/step
# Epoch 41/50
# 30/30 - 0s - loss: 1.2315e-04 - 56ms/epoch - 2ms/step
# Epoch 42/50
# 30/30 - 0s - loss: 1.5106e-04 - 54ms/epoch - 2ms/step
# Epoch 43/50
# 30/30 - 0s - loss: 1.1624e-04 - 55ms/epoch - 2ms/step
# Epoch 44/50
# 30/30 - 0s - loss: 8.4970e-05 - 56ms/epoch - 2ms/step
# Epoch 45/50
# 30/30 - 0s - loss: 7.9309e-05 - 60ms/epoch - 2ms/step
# Epoch 46/50
# 30/30 - 0s - loss: 2.1015e-04 - 57ms/epoch - 2ms/step
# Epoch 47/50
# 30/30 - 0s - loss: 9.9667e-05 - 59ms/epoch - 2ms/step
# Epoch 48/50
# 30/30 - 0s - loss: 1.2569e-04 - 56ms/epoch - 2ms/step
# Epoch 49/50
# 30/30 - 0s - loss: 1.6539e-04 - 57ms/epoch - 2ms/step
# Epoch 50/50
# 30/30 - 0s - loss: 9.2235e-05 - 55ms/epoch - 2ms/step
# Best score: [ -0.000177 ] using param [ {'dropout': 0.0001, 'l1_reg': 5e-06, 'n_units': 22} ]
# Mean of  [ -0.002342 ] , stdev of [ 0.001738 ] using [ {'dropout': 0.0005, 'l1_reg': 1e-06, 'n_units': 14} ]
# Mean of  [ -0.001922 ] , stdev of [ 0.001300 ] using [ {'dropout': 0.0005, 'l1_reg': 1e-06, 'n_units': 16} ]
# Mean of  [ -0.001453 ] , stdev of [ 0.002644 ] using [ {'dropout': 0.0005, 'l1_reg': 1e-06, 'n_units': 18} ]
# Mean of  [ -0.003150 ] , stdev of [ 0.002825 ] using [ {'dropout': 0.0005, 'l1_reg': 1e-06, 'n_units': 20} ]
# Mean of  [ -0.002613 ] , stdev of [ 0.002805 ] using [ {'dropout': 0.0005, 'l1_reg': 1e-06, 'n_units': 22} ]
# Mean of  [ -0.004266 ] , stdev of [ 0.005439 ] using [ {'dropout': 0.0005, 'l1_reg': 5e-06, 'n_units': 14} ]
# Mean of  [ -0.001788 ] , stdev of [ 0.001578 ] using [ {'dropout': 0.0005, 'l1_reg': 5e-06, 'n_units': 16} ]
# Mean of  [ -0.001393 ] , stdev of [ 0.001276 ] using [ {'dropout': 0.0005, 'l1_reg': 5e-06, 'n_units': 18} ]
# Mean of  [ -0.005045 ] , stdev of [ 0.008321 ] using [ {'dropout': 0.0005, 'l1_reg': 5e-06, 'n_units': 20} ]
# Mean of  [ -0.002164 ] , stdev of [ 0.002135 ] using [ {'dropout': 0.0005, 'l1_reg': 5e-06, 'n_units': 22} ]
# Mean of  [ -0.000870 ] , stdev of [ 0.000909 ] using [ {'dropout': 0.0005, 'l1_reg': 1e-05, 'n_units': 14} ]
# Mean of  [ -0.002798 ] , stdev of [ 0.004640 ] using [ {'dropout': 0.0005, 'l1_reg': 1e-05, 'n_units': 16} ]
# Mean of  [ -0.006012 ] , stdev of [ 0.004367 ] using [ {'dropout': 0.0005, 'l1_reg': 1e-05, 'n_units': 18} ]
# Mean of  [ -0.001934 ] , stdev of [ 0.003077 ] using [ {'dropout': 0.0005, 'l1_reg': 1e-05, 'n_units': 20} ]
# Mean of  [ -0.003373 ] , stdev of [ 0.005482 ] using [ {'dropout': 0.0005, 'l1_reg': 1e-05, 'n_units': 22} ]
# Mean of  [ -0.002581 ] , stdev of [ 0.002234 ] using [ {'dropout': 0.0005, 'l1_reg': 5e-05, 'n_units': 14} ]
# Mean of  [ -0.003972 ] , stdev of [ 0.003566 ] using [ {'dropout': 0.0005, 'l1_reg': 5e-05, 'n_units': 16} ]
# Mean of  [ -0.002741 ] , stdev of [ 0.002943 ] using [ {'dropout': 0.0005, 'l1_reg': 5e-05, 'n_units': 18} ]
# Mean of  [ -0.002126 ] , stdev of [ 0.001862 ] using [ {'dropout': 0.0005, 'l1_reg': 5e-05, 'n_units': 20} ]
# Mean of  [ -0.004846 ] , stdev of [ 0.007612 ] using [ {'dropout': 0.0005, 'l1_reg': 5e-05, 'n_units': 22} ]
# Mean of  [ -0.002836 ] , stdev of [ 0.002723 ] using [ {'dropout': 0.0001, 'l1_reg': 1e-06, 'n_units': 14} ]
# Mean of  [ -0.002972 ] , stdev of [ 0.003206 ] using [ {'dropout': 0.0001, 'l1_reg': 1e-06, 'n_units': 16} ]
# Mean of  [ -0.001953 ] , stdev of [ 0.001261 ] using [ {'dropout': 0.0001, 'l1_reg': 1e-06, 'n_units': 18} ]
# Mean of  [ -0.003108 ] , stdev of [ 0.002510 ] using [ {'dropout': 0.0001, 'l1_reg': 1e-06, 'n_units': 20} ]
# Mean of  [ -0.002774 ] , stdev of [ 0.002640 ] using [ {'dropout': 0.0001, 'l1_reg': 1e-06, 'n_units': 22} ]
# Mean of  [ -0.001265 ] , stdev of [ 0.001244 ] using [ {'dropout': 0.0001, 'l1_reg': 5e-06, 'n_units': 14} ]
# Mean of  [ -0.001128 ] , stdev of [ 0.000958 ] using [ {'dropout': 0.0001, 'l1_reg': 5e-06, 'n_units': 16} ]
# Mean of  [ -0.000794 ] , stdev of [ 0.000976 ] using [ {'dropout': 0.0001, 'l1_reg': 5e-06, 'n_units': 18} ]
# Mean of  [ -0.001981 ] , stdev of [ 0.002477 ] using [ {'dropout': 0.0001, 'l1_reg': 5e-06, 'n_units': 20} ]
# Mean of  [ -0.000177 ] , stdev of [ 0.000086 ] using [ {'dropout': 0.0001, 'l1_reg': 5e-06, 'n_units': 22} ]
# Mean of  [ -0.005810 ] , stdev of [ 0.006707 ] using [ {'dropout': 0.0001, 'l1_reg': 1e-05, 'n_units': 14} ]
# Mean of  [ -0.001929 ] , stdev of [ 0.002311 ] using [ {'dropout': 0.0001, 'l1_reg': 1e-05, 'n_units': 16} ]
# Mean of  [ -0.004517 ] , stdev of [ 0.005527 ] using [ {'dropout': 0.0001, 'l1_reg': 1e-05, 'n_units': 18} ]
# Mean of  [ -0.001344 ] , stdev of [ 0.001411 ] using [ {'dropout': 0.0001, 'l1_reg': 1e-05, 'n_units': 20} ]
# Mean of  [ -0.002373 ] , stdev of [ 0.001486 ] using [ {'dropout': 0.0001, 'l1_reg': 1e-05, 'n_units': 22} ]
# Mean of  [ -0.003175 ] , stdev of [ 0.002959 ] using [ {'dropout': 0.0001, 'l1_reg': 5e-05, 'n_units': 14} ]
# Mean of  [ -0.007512 ] , stdev of [ 0.005195 ] using [ {'dropout': 0.0001, 'l1_reg': 5e-05, 'n_units': 16} ]
# Mean of  [ -0.002285 ] , stdev of [ 0.002649 ] using [ {'dropout': 0.0001, 'l1_reg': 5e-05, 'n_units': 18} ]
# Mean of  [ -0.001106 ] , stdev of [ 0.000999 ] using [ {'dropout': 0.0001, 'l1_reg': 5e-05, 'n_units': 20} ]
# Mean of  [ -0.002207 ] , stdev of [ 0.002575 ] using [ {'dropout': 0.0001, 'l1_reg': 5e-05, 'n_units': 22} ]
# Mean of  [ -0.005411 ] , stdev of [ 0.003089 ] using [ {'dropout': 0.005, 'l1_reg': 1e-06, 'n_units': 14} ]
# Mean of  [ -0.013705 ] , stdev of [ 0.013407 ] using [ {'dropout': 0.005, 'l1_reg': 1e-06, 'n_units': 16} ]
# Mean of  [ -0.003165 ] , stdev of [ 0.002751 ] using [ {'dropout': 0.005, 'l1_reg': 1e-06, 'n_units': 18} ]
# Mean of  [ -0.002180 ] , stdev of [ 0.001628 ] using [ {'dropout': 0.005, 'l1_reg': 1e-06, 'n_units': 20} ]
# Mean of  [ -0.002309 ] , stdev of [ 0.001684 ] using [ {'dropout': 0.005, 'l1_reg': 1e-06, 'n_units': 22} ]
# Mean of  [ -0.002596 ] , stdev of [ 0.001641 ] using [ {'dropout': 0.005, 'l1_reg': 5e-06, 'n_units': 14} ]
# Mean of  [ -0.006283 ] , stdev of [ 0.009211 ] using [ {'dropout': 0.005, 'l1_reg': 5e-06, 'n_units': 16} ]
# Mean of  [ -0.003696 ] , stdev of [ 0.004011 ] using [ {'dropout': 0.005, 'l1_reg': 5e-06, 'n_units': 18} ]
# Mean of  [ -0.002350 ] , stdev of [ 0.001568 ] using [ {'dropout': 0.005, 'l1_reg': 5e-06, 'n_units': 20} ]
# Mean of  [ -0.004010 ] , stdev of [ 0.005294 ] using [ {'dropout': 0.005, 'l1_reg': 5e-06, 'n_units': 22} ]
# Mean of  [ -0.002537 ] , stdev of [ 0.002946 ] using [ {'dropout': 0.005, 'l1_reg': 1e-05, 'n_units': 14} ]
# Mean of  [ -0.001810 ] , stdev of [ 0.001403 ] using [ {'dropout': 0.005, 'l1_reg': 1e-05, 'n_units': 16} ]
# Mean of  [ -0.003032 ] , stdev of [ 0.002336 ] using [ {'dropout': 0.005, 'l1_reg': 1e-05, 'n_units': 18} ]
# Mean of  [ -0.000916 ] , stdev of [ 0.000612 ] using [ {'dropout': 0.005, 'l1_reg': 1e-05, 'n_units': 20} ]
# Mean of  [ -0.006888 ] , stdev of [ 0.008607 ] using [ {'dropout': 0.005, 'l1_reg': 1e-05, 'n_units': 22} ]
# Mean of  [ -0.003029 ] , stdev of [ 0.000999 ] using [ {'dropout': 0.005, 'l1_reg': 5e-05, 'n_units': 14} ]
# Mean of  [ -0.003946 ] , stdev of [ 0.001747 ] using [ {'dropout': 0.005, 'l1_reg': 5e-05, 'n_units': 16} ]
# Mean of  [ -0.004545 ] , stdev of [ 0.004490 ] using [ {'dropout': 0.005, 'l1_reg': 5e-05, 'n_units': 18} ]
# Mean of  [ -0.004431 ] , stdev of [ 0.003529 ] using [ {'dropout': 0.005, 'l1_reg': 5e-05, 'n_units': 20} ]
# Mean of  [ -0.002268 ] , stdev of [ 0.001311 ] using [ {'dropout': 0.005, 'l1_reg': 5e-05, 'n_units': 22} ]
# Mean of  [ -0.001974 ] , stdev of [ 0.001197 ] using [ {'dropout': 0.001, 'l1_reg': 1e-06, 'n_units': 14} ]
# Mean of  [ -0.003233 ] , stdev of [ 0.003637 ] using [ {'dropout': 0.001, 'l1_reg': 1e-06, 'n_units': 16} ]
# Mean of  [ -0.003982 ] , stdev of [ 0.004438 ] using [ {'dropout': 0.001, 'l1_reg': 1e-06, 'n_units': 18} ]
# Mean of  [ -0.004130 ] , stdev of [ 0.002672 ] using [ {'dropout': 0.001, 'l1_reg': 1e-06, 'n_units': 20} ]
# Mean of  [ -0.001246 ] , stdev of [ 0.001637 ] using [ {'dropout': 0.001, 'l1_reg': 1e-06, 'n_units': 22} ]
# Mean of  [ -0.003431 ] , stdev of [ 0.004201 ] using [ {'dropout': 0.001, 'l1_reg': 5e-06, 'n_units': 14} ]
# Mean of  [ -0.001391 ] , stdev of [ 0.002007 ] using [ {'dropout': 0.001, 'l1_reg': 5e-06, 'n_units': 16} ]
# Mean of  [ -0.001368 ] , stdev of [ 0.000998 ] using [ {'dropout': 0.001, 'l1_reg': 5e-06, 'n_units': 18} ]
# Mean of  [ -0.003522 ] , stdev of [ 0.002031 ] using [ {'dropout': 0.001, 'l1_reg': 5e-06, 'n_units': 20} ]
# Mean of  [ -0.001034 ] , stdev of [ 0.000782 ] using [ {'dropout': 0.001, 'l1_reg': 5e-06, 'n_units': 22} ]
# Mean of  [ -0.006685 ] , stdev of [ 0.008735 ] using [ {'dropout': 0.001, 'l1_reg': 1e-05, 'n_units': 14} ]
# Mean of  [ -0.001315 ] , stdev of [ 0.001257 ] using [ {'dropout': 0.001, 'l1_reg': 1e-05, 'n_units': 16} ]
# Mean of  [ -0.002082 ] , stdev of [ 0.002343 ] using [ {'dropout': 0.001, 'l1_reg': 1e-05, 'n_units': 18} ]
# Mean of  [ -0.001322 ] , stdev of [ 0.001456 ] using [ {'dropout': 0.001, 'l1_reg': 1e-05, 'n_units': 20} ]
# Mean of  [ -0.000943 ] , stdev of [ 0.000991 ] using [ {'dropout': 0.001, 'l1_reg': 1e-05, 'n_units': 22} ]
# Mean of  [ -0.006023 ] , stdev of [ 0.005412 ] using [ {'dropout': 0.001, 'l1_reg': 5e-05, 'n_units': 14} ]
# Mean of  [ -0.002600 ] , stdev of [ 0.001742 ] using [ {'dropout': 0.001, 'l1_reg': 5e-05, 'n_units': 16} ]
# Mean of  [ -0.009193 ] , stdev of [ 0.008963 ] using [ {'dropout': 0.001, 'l1_reg': 5e-05, 'n_units': 18} ]
# Mean of  [ -0.002607 ] , stdev of [ 0.003602 ] using [ {'dropout': 0.001, 'l1_reg': 5e-05, 'n_units': 20} ]
# Mean of  [ -0.003790 ] , stdev of [ 0.003206 ] using [ {'dropout': 0.001, 'l1_reg': 5e-05, 'n_units': 22} ]

# %%
print('Optimal Model Parameters Derived from 5-fold Cross-Validation:')

for k in params.keys():
    print('   Model: %s, n_units: %f, learning rate: %f, dropout: %f' % 
          (params[k]['label'], params[k]['H'], params[k]['l1_reg'], params[k]['dropout']) )
# Out:
# Optimal Model Parameters Derived from 5-fold Cross-Validation:
#    Model: RNN, n_units: 10.000000, learning rate: 0.000100, dropout: 0.000000
#    Model: Dropout RNN, n_units: 22.000000, learning rate: 0.000005, dropout: 0.000100

# %%
# Store step lag for ease of indexing
step_lag = n_steps + n_steps_ahead - 1

# %%
# Train cross-validated NN model
for k in params.keys():
    tf.random.set_seed(0)
    model = params[k]['function'](data = x_train_reg, n_units = params[k]['H'], 
                                  l1_reg = params[k]['l1_reg'], dropout = params[k]['dropout'] )
    params[k]['history'] = model.fit(x_train_reg, y_train_reg, epochs = n_epoches, 
                                     batch_size = batch_size, callbacks = [es], shuffle = False )
    params[k]['model'] = model
# Out:
# Epoch 1/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.2284
# Epoch 2/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0044
# Epoch 3/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0013
# Epoch 4/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0011
# Epoch 5/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 9.6650e-04
# Epoch 6/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.5272e-04
# Epoch 7/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 9.4458e-04
# Epoch 8/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0010
# Epoch 9/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0011
# Epoch 10/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0011
# Epoch 11/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0011
# Epoch 12/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0010
# Epoch 13/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.6808e-04
# Epoch 14/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 9.4138e-04
# Epoch 15/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.1836e-04
# Epoch 16/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 9.0693e-04
# Epoch 17/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.9357e-04
# Epoch 18/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 8.7326e-04
# Epoch 19/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.5207e-04
# Epoch 20/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 8.2665e-04
# Epoch 21/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 8.0254e-04
# Epoch 22/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 7.8105e-04
# Epoch 23/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 7.5803e-04
# Epoch 24/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 7.4480e-04
# Epoch 25/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 7.3809e-04
# Epoch 26/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 7.2926e-04
# Epoch 27/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 7.2020e-04
# Epoch 28/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 7.1207e-04
# Epoch 29/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 7.0615e-04
# Epoch 30/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 7.0124e-04
# Epoch 31/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.9511e-04
# Epoch 32/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.9050e-04
# Epoch 33/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.8611e-04
# Epoch 34/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.8076e-04
# Epoch 35/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.7304e-04
# Epoch 36/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.7253e-04
# Epoch 37/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.6698e-04
# Epoch 38/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.6311e-04
# Epoch 39/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.5860e-04
# Epoch 40/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.5449e-04
# Epoch 41/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.5208e-04
# Epoch 42/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.5023e-04
# Epoch 43/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.4726e-04
# Epoch 44/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.4475e-04
# Epoch 45/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.3246e-04
# Epoch 46/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.2013e-04
# Epoch 47/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.0679e-04
# Epoch 48/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 5.9315e-04
# Epoch 49/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 5.8511e-04
# Epoch 50/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 5.7957e-04
# Epoch 1/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0470
# Epoch 2/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.6918e-04
# Epoch 3/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.6226e-04
# Epoch 4/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.3287e-04
# Epoch 5/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.8675e-04
# Epoch 6/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.9052e-04
# Epoch 7/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 2.9623e-04
# Epoch 8/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.7833e-04
# Epoch 9/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 2.7913e-04
# Epoch 10/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 2.8351e-04
# Epoch 11/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.8706e-04
# Epoch 12/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.8785e-04
# Epoch 13/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.8585e-04
# Epoch 14/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.9000e-04
# Epoch 15/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.9451e-04
# Epoch 16/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 3.0866e-04
# Epoch 17/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.9076e-04
# Epoch 18/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 2.7913e-04
# Epoch 19/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.7120e-04
# Epoch 20/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.6326e-04
# Epoch 21/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.6217e-04
# Epoch 22/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 2.5549e-04
# Epoch 23/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 2.5360e-04
# Epoch 24/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 2.5449e-04
# Epoch 25/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 2.4208e-04
# Epoch 26/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 2.3621e-04
# Epoch 27/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 2.4093e-04
# Epoch 28/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.3748e-04
# Epoch 29/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.3308e-04
# Epoch 30/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.3155e-04
# Epoch 31/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.1737e-04
# Epoch 32/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.3398e-04
# Epoch 33/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.2403e-04
# Epoch 34/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.3318e-04
# Epoch 35/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.3123e-04
# Epoch 36/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 2.4316e-04
# Epoch 37/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.6615e-04
# Epoch 38/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.8207e-04
# Epoch 39/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 2.9634e-04
# Epoch 40/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 3.0644e-04
# Epoch 41/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 3.3600e-04
# Epoch 42/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 3.5346e-04
# Epoch 43/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 3.5025e-04
# Epoch 44/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 3.5912e-04
# Epoch 45/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 3.7313e-04
# Epoch 46/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 3.6118e-04
# Epoch 47/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 3.7257e-04
# Epoch 48/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 3.7493e-04
# Epoch 49/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 3.8100e-04
# Epoch 50/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 3.7748e-04

# %%
# Prediction on test and train data with NN models
for k in params.keys():
    model = params[k]['model']
    model.summary()

    params[k]['MSE_train'] = mean_squared_error(train[features][step_lag:], model.predict(x_train_reg, verbose = 1))
    params[k]['predict'] = model.predict(x_test_reg, verbose = 1)
    params[k]['MSE_test'] = mean_squared_error(test[features][step_lag:], params[k]['predict'])
# Out:
# Model: "sequential_401"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 10)                120
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 58s 1ms/step
# 11609/11609 [==============================] - 15s 1ms/step
# Model: "sequential_402"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dropout_A (Dropout)         (None, 3, 1)              0
#
#  RNN_A (SimpleRNN)           (None, 22)                528
#
#  Dense_A (Dense)             (None, 1)                 23
#
# =================================================================
# Total params: 551
# Trainable params: 551
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 59s 1ms/step
# 11609/11609 [==============================] - 15s 1ms/step

# %%
# Plot training loss by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 4))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['loss'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
plt.xscale('log')
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('$\log{(n_i)}$ for '  + str(n_epoches) + ' epoches', fontsize = 12)
plt.ylabel('Loss', fontsize = 12)
plt.title('Training Loss By Epoch', fontsize = 18)

plt.show()

# %%
# Plot near_term forecasting residuals for test set
upper_limit = 200
fig = plt.figure(figsize = (15, 10))
_x = np.arange(0, upper_limit).reshape(upper_limit, 1)
colors = pl.cm.jet(np.linspace(1, 0, 4))
i = 0

for k in params.keys():
    residual = params[k]['predict'][:upper_limit] - y_test_reg[:upper_limit].reshape(upper_limit, 1)
    plt.plot(_x, residual, color = colors[i], label = params[k]['label'], alpha = 0.8, linewidth = 0.7)
    i += 1

plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Residual', fontsize = 12)
plt.title('Near-term Forecasting Residual ($\hat{Y_i} - Y_i$)', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Near-term Forecasting Residual ($\\hat{Y_i} - Y_i$)')

# %%
# Plot trimmed residuals for test set
upper_limit = 2000
fig = plt.figure(figsize = (15, 10))
_x = np.arange(0, upper_limit).reshape(upper_limit, 1)
colors = pl.cm.jet(np.linspace(1, 0, 4))
i = 0

for k in params.keys():
    residual = params[k]['predict'][:upper_limit] - y_test_reg[:upper_limit].reshape(upper_limit, 1)
    plt.plot(_x, residual, color = colors[i], label = params[k]['label'], alpha = 0.7, linewidth = 0.7)
    i += 1

plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Residual', fontsize = 12)
plt.title('Trimmed Test Residual ($\hat{Y_i} - Y_i$)', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Trimmed Test Residual ($\\hat{Y_i} - Y_i$)')

# %%
# Plot untrimmed residuals for test set
fig = plt.figure(figsize = (15, 10))
_x = np.arange(0, len(y_test_reg))
colors = pl.cm.jet(np.linspace(1, 0, 4))
i = 0

for k in params.keys():
    residual = params[k]['predict'] - y_test_reg
    plt.plot(_x, residual, color = colors[i], label = params[k]['label'], alpha = 0.7, linewidth = 0.7)
    i += 1

plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Residual', fontsize = 12)
plt.title('Untrimmed Test Residual ($\hat{Y_i} - Y_i$)', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Untrimmed Test Residual ($\\hat{Y_i} - Y_i$)')

# %%
# Plot prediction vs label performance
fig = plt.figure(figsize = (15, 10))
upper_limit = 2000
colors = pl.cm.jet(np.linspace(1, 0, 5))
i = 0

for k in params.keys():
    plt.plot(test.index[step_lag : upper_limit], params[k]['predict'][step_lag : upper_limit], linewidth = 1.0,
             color = colors[i], label = params[k]['label'], alpha = 0.7)
    i += 1
    
plt.plot(test.index[step_lag : upper_limit], test[features][step_lag : upper_limit], linewidth = 0.7,
         color = colors[i], label = 'Observed', alpha = 0.7)

plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Y', fontsize = 12)
plt.title('Label vs Model (Test Data)', fontsize = 18)

plt.show()

# %%
# Plot prediction vs label error
fig = plt.figure(figsize = (15, 10))
dim = len(test.index[step_lag : upper_limit])
x_plot = test.index[step_lag : upper_limit]
colors = pl.cm.jet(np.linspace(1, 0, 4))
i = 0

for k in params.keys():
    nn_y_plot = test[features][step_lag : upper_limit] - params[k]['predict'][: upper_limit - (step_lag), 0].reshape(dim, 1)
    plt.plot(x_plot, nn_y_plot, color = colors[i], label = params[k]['label'] + " (" + str( round( params[k]['MSE_test'], 7) ) + ")",
             alpha = 0.7, linewidth = 0.7)
    i += 1

plt.legend(loc = 'best', title = 'Model (Test MSE)', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Y - $\hat{Y}$', fontsize = 12)
plt.title('Trimmed Label vs Model Error (Training Data)', fontsize = 18)

plt.show()

# %%
print('Model Errors:')

for k in params.keys():
    print('Model: ' + params[k]['label'])
    print('   Train MSE = ' + str(params[k]['MSE_train']))
    print('   Test MSE = ' + str(params[k]['MSE_test']))
    print()
# Out:
# Model Errors:
# Model: RNN
#    Train MSE = 0.0020183333301026355
#    Test MSE = 0.1757872288316143
#
# Model: Dropout RNN
#    Train MSE = 0.001535569069841281
#    Test MSE = 1.425740244495521

# %%
print('Near-term Forecasting Error')
print()

for k in params.keys():
    print('Model: ' + params[k]['label'])
    temp = mean_squared_error(test[features][step_lag : 200], params[k]['predict'][step_lag : 200])
    print('   MSE = ' + str(temp))
    print()
# Out:
# Near-term Forecasting Error
#
# Model: RNN
#    MSE = 1.2372096415300602e-06
#
# Model: Dropout RNN
#    MSE = 1.9436148138206074e-06

# %%
print('5-Fold GridCV Results')
print()

for k in params.keys():
    print('Model: ' + params[k]['label'])
    print(params[k]['cv_results'])
# Out:
# 5-Fold GridCV Results
#
# Model: RNN
#
# Model: Dropout RNN
# {'mean_fit_time': array([2.82612967, 2.36872091, 2.09261813, 2.29389782, 2.30390844,
#        2.13456168, 2.21135674, 2.15789557, 2.24410915, 2.17532897,
#        2.21632419, 2.24793005, 2.36946211, 2.16946893, 2.16765718,
#        2.16640244, 2.16323218, 2.24212084, 2.14389038, 2.30264745,
#        2.32791572, 2.32935314, 2.23830853, 2.18034821, 2.25701742,
#        2.21382055, 2.24101233, 2.32733164, 2.23978558, 2.15073767,
#        2.15169673, 2.39728856, 2.15512061, 2.21037822, 2.31937284,
#        2.38414783, 2.43415418, 2.30032992, 2.15836406, 2.31055417,
#        2.14761577, 2.23009686, 2.40604434, 2.13726997, 2.29606996,
#        2.2202261 , 2.14857674, 2.31740594, 2.23434157, 2.13963089,
#        2.22384906, 2.15183172, 2.42279029, 2.32446218, 2.20572314,
#        2.20148759, 2.41742444, 2.20624824, 2.31338582, 2.18993297,
#        2.24758668, 2.22647038, 2.31693959, 2.15110936, 2.31993876,
#        2.14948177, 2.20846996, 2.21933327, 2.48037071, 2.13136973,
#        2.15679526, 2.22454572, 2.15296187, 2.29857626, 2.13728046,
#        2.46574464, 2.18326135, 2.15559282, 2.31708937, 2.16164436]), 'std_fit_time': array([0.50090289, 0.78309277, 0.61858813, 0.59105911, 0.48308062,
#        0.59908026, 0.6921935 , 0.61028554, 0.74604468, 0.62879551,
#        0.6918898 , 0.69185497, 0.57813534, 0.62041453, 0.61935959,
#        0.60490417, 0.61978168, 0.68945293, 0.61959039, 0.77181591,
#        0.57514938, 0.68958853, 0.53191386, 0.61635059, 0.6276069 ,
#        0.61482944, 0.61599783, 0.71816289, 0.68726292, 0.6240998 ,
#        0.59291166, 0.64296567, 0.60724757, 0.60254445, 0.68489977,
#        0.77120283, 0.58906759, 0.77386237, 0.61783743, 0.60283423,
#        0.615636  , 0.69646554, 0.51977291, 0.6049991 , 0.65747783,
#        0.49322954, 0.62174182, 0.70773981, 0.72612848, 0.61573091,
#        0.69614585, 0.59267926, 0.60048346, 0.70319169, 0.48923436,
#        0.64667102, 0.65444055, 0.67297327, 0.68776201, 0.7145809 ,
#        0.49459835, 0.48385347, 0.44309884, 0.60020641, 0.58756793,
#        0.61113198, 0.65026497, 0.6938503 , 0.65686397, 0.60755973,
#        0.59752881, 0.51077947, 0.615002  , 0.64847965, 0.6152209 ,
#        0.65746501, 0.63484161, 0.60639427, 0.7088118 , 0.62451326]), 'mean_score_time': array([0.17952275, 0.15071721, 0.20562735, 0.14636893, 0.23238816,
