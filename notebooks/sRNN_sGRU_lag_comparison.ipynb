# %%
# standard
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
# statsmodels
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA
# os
import os
# sklearn
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
# tf
import tensorflow as tf
# keras
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Layer, GRU, LSTM, SimpleRNN, Dense, Activation, Bidirectional
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
from keras import optimizers
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
from keras.regularizers import l1,l2
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Import btc
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Make pd df
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NN - 434/btc.csv')

# %%
df.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0            4.39
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# Drop extraneous columns
df.drop(['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume_(BTC)', 'Volume_(Currency)'], axis = 1, inplace = True)
# Drop bottom 3m rows and top 800k
df.drop(df.index[:3000000], axis = 0, inplace = True)
df.drop(df.index[4000000:], axis = 0, inplace = True)
# Reset index; drop column
df.reset_index(drop = True, inplace = True)
# Backfill na's
df.fillna(method = 'backfill', inplace = True)

# %%
# RNN target/features
features = ['Weighted_Price']
target = 'Weighted_Price'

# %%
# Split train sets
train_weight = 0.8
df_split = int( len(df) * train_weight )

train = df.iloc[:df_split]
test = df.iloc[df_split:]

# %%
# Scaling parameters
mu = float( train[features].mean() )
sigma = float( train[features].std() )

# Scale data
train = train[features].apply( lambda x: (x - mu) / sigma )
test = test[features].apply( lambda x: (x - mu) / sigma )

# %%
'''
Function for reshaping data into one-step ahead time series prediction format
    value: feature value to be lagged
    n_steps: number of steps/sequence length
    n_steps_ahead: forecasting horizon
'''

def get_lagged_features(value, n_steps, n_steps_ahead):
    lag_list = []
    for lag in range(n_steps + n_steps_ahead - 1, n_steps_ahead - 1, -1):
        lag_list.append( value.shift(lag) )
    return pd.concat(lag_list, axis = 1)

# %%
'''
Function for altering train/test time-series into n-step lagged data
    _train: train data
    _test: test data
    n_steps: number of lags
'''

def lag_train_test(_train = train, _test = test, n_steps = 3):
    n_steps_ahead = n_steps

    # Transform training input and output data
    col_ords = []
    for i in range(n_steps):
        for j in range(len(features)):
            col_ords.append(i + j * n_steps)

    x_train_list = []
    for f in features:
        x_train_reg = get_lagged_features(train, n_steps, n_steps).dropna()
        x_train_list.append(x_train_reg)
    x_train_reg = pd.concat(x_train_list, axis = 1)
            
    x_train_reg = x_train_reg.iloc[:, col_ords]
    y_train_reg = train.loc[x_train_reg.index, [target]].values
    x_train_reg = np.reshape( x_train_reg.values, ( x_train_reg.shape[0], int( x_train_reg.shape[1] / len(features)), len(features) ) )
    y_train_reg = np.reshape( y_train_reg, (y_train_reg.shape[0], 1, 1))

    # Transform test input and output data
    x_test_list = []
    for f in features:
        x_test_reg = get_lagged_features(test, n_steps, n_steps).dropna()
        x_test_list.append(x_test_reg)
    x_test_reg = pd.concat(x_test_list, axis = 1)

    x_test_reg = x_test_reg.iloc[:, col_ords]
    y_test_reg = test.loc[x_test_reg.index, [target]].values
    x_test_reg = np.reshape( x_test_reg.values, ( x_test_reg.shape[0], int( x_test_reg.shape[1] / len(features)), len(features) ) )
    y_test_reg = np.reshape( y_test_reg, (y_test_reg.shape[0], 1, 1))

    print('Data transformed to have ' + str(n_steps) + ' step-lags...')
    print('   Regularized x training set shape: ' + str(x_train_reg.shape))
    print('   Regularized x testing set shape: ' + str(x_test_reg.shape))
    print('   Regularized y training set shape: ' + str(y_train_reg.shape))
    print('   Regularized y testing set shape: ' + str(y_test_reg.shape))

    return [x_train_reg, x_test_reg, y_train_reg, y_test_reg]

# %%
# Custom activation function
def swish(x):
    return (K.sigmoid(x) * x)

get_custom_objects().update({'swish': Activation(swish)})

# %%
# NN structures - SWISH
def _sRNN(data = train, n_units = 10, l1_reg = 0.0001, seed = 0, optim = 'adam'):
    model = Sequential()
    model.add( 
        SimpleRNN(n_units,
                  activation = 'swish', 
                  kernel_initializer = keras.initializers.glorot_uniform(seed), 
                  bias_initializer = keras.initializers.glorot_uniform(seed), 
                  recurrent_initializer = keras.initializers.orthogonal(seed), 
                  kernel_regularizer = l1(l1_reg), 
                  input_shape = (data.shape[1], data.shape[-1]),
                  unroll = True,
                  stateful = False) )  
    model.add(
        Dense(1, 
              kernel_initializer = keras.initializers.glorot_uniform(seed), 
              bias_initializer = keras.initializers.glorot_uniform(seed), 
              kernel_regularizer = l1(l1_reg) ) )
    model.compile(loss = 'mean_squared_error', optimizer = optim)
    return model

def _sGRU(data = train, n_units = 12, l1_reg = 0.00001, seed = 0, optim = 'adam'):
    model = Sequential()
    model.add(
        GRU(n_units,
             activation = 'swish',
             kernel_initializer = keras.initializers.glorot_uniform(seed), 
             bias_initializer = keras.initializers.glorot_uniform(seed), 
             recurrent_initializer = keras.initializers.orthogonal(seed), 
             kernel_regularizer = l1(l1_reg), 
             input_shape = (data.shape[1], data.shape[-1]),
             unroll = True,
             stateful = False) )
    model.add(
        Dense(1,
              kernel_initializer = keras.initializers.glorot_uniform(seed), 
              bias_initializer = keras.initializers.glorot_uniform(seed), 
              kernel_regularizer = l1(l1_reg) ) )
    model.compile(loss = 'mean_squared_error', optimizer = optim)
    return model

# %%
# Hyperparameters
n_epoches = 50
batch_size = 1000

# %%
# Implement early stopping monitor to speed up cross validation
es = EarlyStopping(monitor = 'loss', mode = 'min', verbose = 1, patience = 100, 
                   min_delta = 1e-7, restore_best_weights = True)

# %%
# NN models
params = {
    'srnn_3lag': {'model':'', 'function':_sRNN, 'data':[], 'H':10, 'l1_reg':0.0001, 'n_lags':3, 'label':'sRNN - 3', 'history':'', 'cv_results':''},
    'srnn_5lag': {'model':'', 'function':_sRNN, 'data':[], 'H':10, 'l1_reg':0.0001, 'n_lags':5, 'label':'sRNN - 5', 'history':'', 'cv_results':''},
    'srnn_7lag': {'model':'', 'function':_sRNN, 'data':[], 'H':10, 'l1_reg':0.0001, 'n_lags':7, 'label':'sRNN - 7', 'history':'', 'cv_results':''},
    'srnn_9lag': {'model':'', 'function':_sRNN, 'data':[], 'H':10, 'l1_reg':0.0001, 'n_lags':9, 'label':'sRNN - 9', 'history':'', 'cv_results':''},
    'sgru_3lag': {'model':'', 'function':_sGRU, 'data':[], 'H':12, 'l1_reg':0.00001, 'n_lags':3, 'label':'sGRU - 3', 'history':'', 'cv_results':''},
    'sgru_5lag': {'model':'', 'function':_sGRU, 'data':[], 'H':12, 'l1_reg':0.00001, 'n_lags':5, 'label':'sGRU - 5', 'history':'', 'cv_results':''},
    'sgru_7lag': {'model':'', 'function':_sGRU, 'data':[], 'H':12, 'l1_reg':0.00001, 'n_lags':7, 'label':'sGRU - 7', 'history':'', 'cv_results':''},
    'sgru_9lag': {'model':'', 'function':_sGRU, 'data':[], 'H':12, 'l1_reg':0.00001, 'n_lags':9, 'label':'sGRU - 9', 'history':'', 'cv_results':''}
}

# %%
# Produce lagged data; store in params

for k in params.keys():
    params[k]['data'] = lag_train_test(train, test, params[k]['n_lags'])
# Out:
# Data transformed to have 3 step-lags...
#    Regularized x training set shape: (1485896, 3, 1)
#    Regularized x testing set shape: (371471, 3, 1)
#    Regularized y training set shape: (1485896, 1, 1)
#    Regularized y testing set shape: (371471, 1, 1)
# Data transformed to have 5 step-lags...
#    Regularized x training set shape: (1485892, 5, 1)
#    Regularized x testing set shape: (371467, 5, 1)
#    Regularized y training set shape: (1485892, 1, 1)
#    Regularized y testing set shape: (371467, 1, 1)
# Data transformed to have 7 step-lags...
#    Regularized x training set shape: (1485888, 7, 1)
#    Regularized x testing set shape: (371463, 7, 1)
#    Regularized y training set shape: (1485888, 1, 1)
#    Regularized y testing set shape: (371463, 1, 1)
# Data transformed to have 9 step-lags...
#    Regularized x training set shape: (1485884, 9, 1)
#    Regularized x testing set shape: (371459, 9, 1)
#    Regularized y training set shape: (1485884, 1, 1)
#    Regularized y testing set shape: (371459, 1, 1)
# Data transformed to have 3 step-lags...
#    Regularized x training set shape: (1485896, 3, 1)
#    Regularized x testing set shape: (371471, 3, 1)
#    Regularized y training set shape: (1485896, 1, 1)
#    Regularized y testing set shape: (371471, 1, 1)
# Data transformed to have 5 step-lags...
#    Regularized x training set shape: (1485892, 5, 1)
#    Regularized x testing set shape: (371467, 5, 1)
#    Regularized y training set shape: (1485892, 1, 1)
#    Regularized y testing set shape: (371467, 1, 1)
# Data transformed to have 7 step-lags...
#    Regularized x training set shape: (1485888, 7, 1)
#    Regularized x testing set shape: (371463, 7, 1)
#    Regularized y training set shape: (1485888, 1, 1)
#    Regularized y testing set shape: (371463, 1, 1)
# Data transformed to have 9 step-lags...
#    Regularized x training set shape: (1485884, 9, 1)
#    Regularized x testing set shape: (371459, 9, 1)
#    Regularized y training set shape: (1485884, 1, 1)
#    Regularized y testing set shape: (371459, 1, 1)

# %%
# Train
for k in params.keys():
    tf.random.set_seed(0)
    model = params[k]['function'](params[k]['data'][0], params[k]['H'], params[k]['l1_reg'] )
    params[k]['history'] = model.fit(params[k]['data'][0], params[k]['data'][2], epochs = n_epoches, 
                                     batch_size = batch_size, callbacks = [es], shuffle = False )
    params[k]['model'] = model
# Out:
# Epoch 1/50
# 1486/1486 [==============================] - 6s 2ms/step - loss: 0.2284
# Epoch 2/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0044
# Epoch 3/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0013
# Epoch 4/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0011
# Epoch 5/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 9.6650e-04
# Epoch 6/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 9.5272e-04
# Epoch 7/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 9.4458e-04
# Epoch 8/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0010
# Epoch 9/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0011
# Epoch 10/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0011
# Epoch 11/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0011
# Epoch 12/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0010
# Epoch 13/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 9.6808e-04
# Epoch 14/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 9.4138e-04
# Epoch 15/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 9.1835e-04
# Epoch 16/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 9.0699e-04
# Epoch 17/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 8.9360e-04
# Epoch 18/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 8.7326e-04
# Epoch 19/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 8.5263e-04
# Epoch 20/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 8.2727e-04
# Epoch 21/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 8.0353e-04
# Epoch 22/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 7.7935e-04
# Epoch 23/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 7.5979e-04
# Epoch 24/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 7.4345e-04
# Epoch 25/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 7.3499e-04
# Epoch 26/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 7.2733e-04
# Epoch 27/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 7.1952e-04
# Epoch 28/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 7.1279e-04
# Epoch 29/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 7.0542e-04
# Epoch 30/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 7.0070e-04
# Epoch 31/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 6.9387e-04
# Epoch 32/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 6.8836e-04
# Epoch 33/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 6.8537e-04
# Epoch 34/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.8219e-04
# Epoch 35/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 6.7709e-04
# Epoch 36/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 6.7150e-04
# Epoch 37/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 6.6595e-04
# Epoch 38/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 6.6056e-04
# Epoch 39/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 6.5717e-04
# Epoch 40/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.5343e-04
# Epoch 41/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.5004e-04
# Epoch 42/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.4850e-04
# Epoch 43/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.4693e-04
# Epoch 44/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.4332e-04
# Epoch 45/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 6.3455e-04
# Epoch 46/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 6.2046e-04
# Epoch 47/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 6.0806e-04
# Epoch 48/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 5.9302e-04
# Epoch 49/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 5.8471e-04
# Epoch 50/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 5.8061e-04
# Epoch 1/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.2207
# Epoch 2/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0034
# Epoch 3/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0013
# Epoch 4/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0011
# Epoch 5/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.8004e-04
# Epoch 6/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0010
# Epoch 7/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0012
# Epoch 8/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0014
# Epoch 9/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0014
# Epoch 10/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0013
# Epoch 11/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0013
# Epoch 12/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0012
# Epoch 13/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0011
# Epoch 14/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0011
# Epoch 15/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0010
# Epoch 16/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.8985e-04
# Epoch 17/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.6639e-04
# Epoch 18/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.4040e-04
# Epoch 19/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.1836e-04
# Epoch 20/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.0145e-04
# Epoch 21/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.8342e-04
# Epoch 22/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.6828e-04
# Epoch 23/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.5772e-04
# Epoch 24/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.4140e-04
# Epoch 25/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.2712e-04
# Epoch 26/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.1452e-04
# Epoch 27/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.0144e-04
# Epoch 28/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.9052e-04
# Epoch 29/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.7995e-04
# Epoch 30/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.7207e-04
# Epoch 31/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.4943e-04
# Epoch 32/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.2490e-04
# Epoch 33/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.2589e-04
# Epoch 34/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.4173e-04
# Epoch 35/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.1235e-04
# Epoch 36/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.9814e-04
# Epoch 37/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.0412e-04
# Epoch 38/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.1557e-04
# Epoch 39/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.9213e-04
# Epoch 40/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.8353e-04
# Epoch 41/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.9145e-04
# Epoch 42/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.9519e-04
# Epoch 43/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.7813e-04
# Epoch 44/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.7310e-04
# Epoch 45/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.7521e-04
# Epoch 46/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.7351e-04
# Epoch 47/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.6469e-04
# Epoch 48/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.5885e-04
# Epoch 49/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.5943e-04
# Epoch 50/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.5915e-04
# Epoch 1/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 0.2201
# Epoch 2/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0030
# Epoch 3/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0013
# Epoch 4/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0011
# Epoch 5/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0010
# Epoch 6/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0012
# Epoch 7/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 0.0016
# Epoch 8/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 0.0015
# Epoch 9/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0015
# Epoch 10/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0014
# Epoch 11/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0013
# Epoch 12/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0013
# Epoch 13/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0012
# Epoch 14/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0011
# Epoch 15/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0011
# Epoch 16/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0010
# Epoch 17/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0010
# Epoch 18/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.7723e-04
# Epoch 19/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.6017e-04
# Epoch 20/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.4547e-04
# Epoch 21/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.3343e-04
# Epoch 22/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.2301e-04
# Epoch 23/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.0829e-04
# Epoch 24/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.9266e-04
# Epoch 25/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.8220e-04
# Epoch 26/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.7050e-04
# Epoch 27/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.5995e-04
# Epoch 28/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.4841e-04
# Epoch 29/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.4445e-04
# Epoch 30/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.3675e-04
# Epoch 31/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.2789e-04
# Epoch 32/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.2215e-04
# Epoch 33/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.1475e-04
# Epoch 34/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.0646e-04
# Epoch 35/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.9857e-04
# Epoch 36/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.9484e-04
# Epoch 37/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.8948e-04
# Epoch 38/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.8623e-04
# Epoch 39/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.8332e-04
# Epoch 40/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.8149e-04
# Epoch 41/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.7912e-04
# Epoch 42/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.7661e-04
# Epoch 43/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.7496e-04
# Epoch 44/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.7186e-04
# Epoch 45/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.6768e-04
# Epoch 46/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.6395e-04
# Epoch 47/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.5949e-04
# Epoch 48/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.5611e-04
# Epoch 49/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.5456e-04
# Epoch 50/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.5053e-04
# Epoch 1/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 0.2200
# Epoch 2/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0029
# Epoch 3/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0013
# Epoch 4/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0012
# Epoch 5/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0011
# Epoch 6/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0013
# Epoch 7/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0016
# Epoch 8/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0016
# Epoch 9/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 0.0016
# Epoch 10/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0015
# Epoch 11/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 0.0014
# Epoch 12/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0013
# Epoch 13/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0012
# Epoch 14/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0011
# Epoch 15/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0011
# Epoch 16/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0011
# Epoch 17/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0010
# Epoch 18/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0010
# Epoch 19/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0010
# Epoch 20/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.8477e-04
# Epoch 21/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.6765e-04
# Epoch 22/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.5817e-04
# Epoch 23/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.4355e-04
# Epoch 24/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.2678e-04
# Epoch 25/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.1398e-04
# Epoch 26/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.0051e-04
# Epoch 27/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.8875e-04
# Epoch 28/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.8167e-04
# Epoch 29/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.7435e-04
# Epoch 30/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.6534e-04
# Epoch 31/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.5717e-04
# Epoch 32/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.4796e-04
# Epoch 33/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.4309e-04
# Epoch 34/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.3030e-04
# Epoch 35/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.2463e-04
# Epoch 36/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.1888e-04
# Epoch 37/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.0966e-04
# Epoch 38/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.0225e-04
# Epoch 39/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.9876e-04
# Epoch 40/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.9696e-04
# Epoch 41/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.9654e-04
# Epoch 42/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.8886e-04
# Epoch 43/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.7944e-04
# Epoch 44/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 7.7357e-04
# Epoch 45/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.7273e-04
# Epoch 46/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.6564e-04
# Epoch 47/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.6273e-04
# Epoch 48/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.6071e-04
# Epoch 49/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.5533e-04
# Epoch 50/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.5019e-04
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 0.0816
# Epoch 2/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 3.3821e-04
# Epoch 3/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.2502e-04
# Epoch 4/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3286e-04
# Epoch 5/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.1426e-04
# Epoch 6/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.1781e-04
# Epoch 7/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.1264e-04
# Epoch 8/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.0469e-04
# Epoch 9/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 1.9779e-04
# Epoch 10/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 1.9554e-04
# Epoch 11/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 1.9335e-04
# Epoch 12/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 1.9263e-04
# Epoch 13/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 1.9600e-04
# Epoch 14/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.0630e-04
# Epoch 15/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.1916e-04
# Epoch 16/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.2693e-04
# Epoch 17/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.4313e-04
# Epoch 18/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.6669e-04
# Epoch 19/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 3.0342e-04
# Epoch 20/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 3.5198e-04
# Epoch 21/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 3.4200e-04
# Epoch 22/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 3.2021e-04
# Epoch 23/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 3.0201e-04
# Epoch 24/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.9072e-04
# Epoch 25/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.8585e-04
# Epoch 26/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.8335e-04
# Epoch 27/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.8164e-04
# Epoch 28/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.7869e-04
# Epoch 29/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.7406e-04
# Epoch 30/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.6889e-04
# Epoch 31/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.6298e-04
# Epoch 32/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.5691e-04
# Epoch 33/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.5023e-04
# Epoch 34/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.4575e-04
# Epoch 35/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.4296e-04
# Epoch 36/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.4108e-04
# Epoch 37/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3992e-04
# Epoch 38/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3916e-04
# Epoch 39/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3842e-04
# Epoch 40/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3773e-04
# Epoch 41/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3719e-04
# Epoch 42/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3718e-04
# Epoch 43/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3810e-04
# Epoch 44/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.4027e-04
# Epoch 45/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.4386e-04
# Epoch 46/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.4904e-04
# Epoch 47/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.5472e-04
# Epoch 48/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.5984e-04
# Epoch 49/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.6418e-04
# Epoch 50/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.6754e-04
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 0.0664
# Epoch 2/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.2035e-04
# Epoch 3/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.5438e-04
# Epoch 4/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.6358e-04
# Epoch 5/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.6079e-04
# Epoch 6/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.7698e-04
# Epoch 7/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.7931e-04
# Epoch 8/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.7832e-04
# Epoch 9/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.7653e-04
# Epoch 10/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.8115e-04
# Epoch 11/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.8955e-04
# Epoch 12/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.0417e-04
# Epoch 13/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.2667e-04
# Epoch 14/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.5929e-04
# Epoch 15/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 4.1431e-04
# Epoch 16/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 4.4383e-04
# Epoch 17/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 4.3213e-04
# Epoch 18/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 4.1352e-04
# Epoch 19/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.9921e-04
# Epoch 20/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.9114e-04
# Epoch 21/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.8953e-04
# Epoch 22/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.9146e-04
# Epoch 23/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.9276e-04
# Epoch 24/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.9095e-04
# Epoch 25/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.8638e-04
# Epoch 26/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.8063e-04
# Epoch 27/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.7415e-04
# Epoch 28/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.6928e-04
# Epoch 29/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.6863e-04
# Epoch 30/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.6832e-04
# Epoch 31/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.6855e-04
# Epoch 32/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.7006e-04
# Epoch 33/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.7096e-04
# Epoch 34/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.6932e-04
# Epoch 35/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.6434e-04
# Epoch 36/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.5713e-04
# Epoch 37/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.4897e-04
# Epoch 38/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.4096e-04
# Epoch 39/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.3342e-04
# Epoch 40/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.2633e-04
# Epoch 41/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.1966e-04
# Epoch 42/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.1375e-04
# Epoch 43/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.0870e-04
# Epoch 44/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.0459e-04
# Epoch 45/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.0161e-04
# Epoch 46/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.9972e-04
# Epoch 47/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.9885e-04
# Epoch 48/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.9796e-04
# Epoch 49/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.9555e-04
# Epoch 50/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.9120e-04
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 0.0621
# Epoch 2/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.5030e-04
# Epoch 3/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 2.8698e-04
# Epoch 4/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 2.9148e-04
# Epoch 5/50
# 1486/1486 [==============================] - 7s 5ms/step - loss: 3.1165e-04
# Epoch 6/50
# 1486/1486 [==============================] - 7s 5ms/step - loss: 3.3458e-04
# Epoch 7/50
# 1486/1486 [==============================] - 7s 5ms/step - loss: 3.2757e-04
# Epoch 8/50
# 1486/1486 [==============================] - 7s 5ms/step - loss: 3.2574e-04
# Epoch 9/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.2749e-04
# Epoch 10/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.3260e-04
# Epoch 11/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.4233e-04
# Epoch 12/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.6094e-04
# Epoch 13/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.8901e-04
# Epoch 14/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.2950e-04
# Epoch 15/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.9751e-04
# Epoch 16/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 5.3878e-04
# Epoch 17/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 5.1727e-04
# Epoch 18/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.9630e-04
# Epoch 19/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.8264e-04
# Epoch 20/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.7521e-04
# Epoch 21/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.7199e-04
# Epoch 22/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.6885e-04
# Epoch 23/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.6421e-04
# Epoch 24/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.5702e-04
# Epoch 25/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.4847e-04
# Epoch 26/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.3919e-04
# Epoch 27/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.2961e-04
# Epoch 28/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.1985e-04
# Epoch 29/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.1060e-04
# Epoch 30/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 4.0158e-04
# Epoch 31/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.9275e-04
# Epoch 32/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.8404e-04
# Epoch 33/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.7556e-04
# Epoch 34/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.6755e-04
# Epoch 35/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.6008e-04
# Epoch 36/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.5312e-04
# Epoch 37/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.4679e-04
# Epoch 38/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.4115e-04
# Epoch 39/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.3626e-04
# Epoch 40/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.3232e-04
# Epoch 41/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.2951e-04
# Epoch 42/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.2794e-04
# Epoch 43/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.2776e-04
# Epoch 44/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.2925e-04
# Epoch 45/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.3195e-04
# Epoch 46/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.3245e-04
# Epoch 47/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.2844e-04
# Epoch 48/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.2266e-04
# Epoch 49/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.1891e-04
# Epoch 50/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 3.1815e-04
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 1486/1486 [==============================] - 10s 5ms/step - loss: 0.0606
# Epoch 2/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.8602e-04
# Epoch 3/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.1980e-04
# Epoch 4/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.2543e-04
# Epoch 5/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.7150e-04
# Epoch 6/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.8049e-04
# Epoch 7/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.7818e-04
# Epoch 8/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.8415e-04
# Epoch 9/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.9048e-04
# Epoch 10/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.0801e-04
# Epoch 11/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.4028e-04
# Epoch 12/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.9271e-04
# Epoch 13/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 5.7388e-04
# Epoch 14/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 6.1820e-04
# Epoch 15/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 5.9211e-04
# Epoch 16/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 5.7052e-04
# Epoch 17/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 5.5719e-04
# Epoch 18/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 5.4887e-04
# Epoch 19/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 5.4374e-04
# Epoch 20/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 5.3678e-04
# Epoch 21/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 5.2656e-04
# Epoch 22/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 5.1295e-04
# Epoch 23/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.9735e-04
# Epoch 24/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.8257e-04
# Epoch 25/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.6795e-04
# Epoch 26/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.5407e-04
# Epoch 27/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.4259e-04
# Epoch 28/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.3255e-04
# Epoch 29/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.2372e-04
# Epoch 30/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.1544e-04
# Epoch 31/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.0760e-04
# Epoch 32/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 4.0020e-04
# Epoch 33/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.9325e-04
# Epoch 34/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.8683e-04
# Epoch 35/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.8103e-04
# Epoch 36/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.7581e-04
# Epoch 37/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.7138e-04
# Epoch 38/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.6768e-04
# Epoch 39/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.6469e-04
# Epoch 40/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.6241e-04
# Epoch 41/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.6071e-04
# Epoch 42/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.5966e-04
# Epoch 43/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.5878e-04
# Epoch 44/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.5853e-04
# Epoch 45/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.5979e-04
# Epoch 46/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.6203e-04
# Epoch 47/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.6348e-04
# Epoch 48/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.6253e-04
# Epoch 49/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.6017e-04
# Epoch 50/50
# 1486/1486 [==============================] - 8s 5ms/step - loss: 3.5851e-04

# %%
# Prediction on test and train data with NN models
for k in params.keys():
    step_lag = params[k]['n_lags'] + params[k]['n_lags'] - 1
    model = params[k]['model']
    model.summary()

    params[k]['MSE_train'] = mean_squared_error(train[features][step_lag:], 
                                                model.predict(params[k]['data'][0], verbose = 1))
    params[k]['predict'] = model.predict(params[k]['data'][1], verbose = 1)
    params[k]['MSE_test'] = mean_squared_error(test[features][step_lag:],
                                               params[k]['predict'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 10)                120
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 56s 1ms/step
# 11609/11609 [==============================] - 14s 1ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 10)                120
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 60s 1ms/step
# 11609/11609 [==============================] - 15s 1ms/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_2 (SimpleRNN)    (None, 10)                120
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# 46434/46434 [==============================] - 62s 1ms/step
# 11609/11609 [==============================] - 19s 2ms/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 10)                120
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# 46434/46434 [==============================] - 66s 1ms/step
# 11609/11609 [==============================] - 17s 1ms/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 12)                540
#
#  dense_4 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 553
# Trainable params: 553
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 68s 1ms/step
# 11609/11609 [==============================] - 17s 1ms/step
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 12)                540
#
#  dense_5 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 553
# Trainable params: 553
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 80s 2ms/step
# 11609/11609 [==============================] - 20s 2ms/step
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_2 (GRU)                 (None, 12)                540
#
#  dense_6 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 553
# Trainable params: 553
# Non-trainable params: 0
# _________________________________________________________________
# 46434/46434 [==============================] - 89s 2ms/step
# 11609/11609 [==============================] - 26s 2ms/step
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 12)                540
#
#  dense_7 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 553
# Trainable params: 553
# Non-trainable params: 0
# _________________________________________________________________
# 46434/46434 [==============================] - 103s 2ms/step
# 11609/11609 [==============================] - 26s 2ms/step

# %%
# Plot training loss by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(0, 1, 8))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['loss'], color = colors[i],
             label = params[k]['label'], alpha = 0.8)
    i += 1
    

plt.yscale('log')
plt.legend(loc = 'best', title = 'Model - # Lags', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('$\log{(loss)}$', fontsize = 12)
plt.title('Training Loss By Epoch', fontsize = 18)

plt.show()

# %%
# Plot untrimmed residuals for test set - sRNN
test_length = 371457
fig = plt.figure(figsize = (18, 12))
_x = np.arange(0, test_length).reshape(test_length, 1)
colors = pl.cm.jet(np.linspace(1, 0, 4))
i = 0

for k in ['srnn_3lag', 'srnn_5lag', 'srnn_7lag', 'srnn_9lag']:
    residual = params[k]['predict'][:test_length] - params[k]['data'][3][:test_length].reshape(test_length, 1)
    plt.plot(_x, residual, color = colors[i], label = params[k]['label'], alpha = 0.7, linewidth = 0.7)
    i += 1

plt.legend(loc = 'best', title = 'Model - # Lags', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Residual', fontsize = 12)
plt.title('RNN (swish) - Untrimmed Test Residual ($\hat{Y_i} - Y_i$)', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'RNN (swish) - Untrimmed Test Residual ($\\hat{Y_i} - Y_i$)')

# %%
# Plot untrimmed residuals for test set - sGRU
test_length = 371457
fig = plt.figure(figsize = (18, 12))
_x = np.arange(0, test_length).reshape(test_length, 1)
colors = pl.cm.jet(np.linspace(1, 0, 4))
i = 0

for k in ['sgru_3lag', 'sgru_5lag', 'sgru_7lag', 'sgru_9lag']:
    residual = params[k]['predict'][:test_length] - params[k]['data'][3][:test_length].reshape(test_length, 1)
    plt.plot(_x, residual, color = colors[i], label = params[k]['label'], alpha = 0.7, linewidth = 0.7)
    i += 1

plt.legend(loc = 'best', title = 'Model - # Lags', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Residual', fontsize = 12)
plt.title('GRU (swish) - Untrimmed Test Residual ($\hat{Y_i} - Y_i$)', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'GRU (swish) - Untrimmed Test Residual ($\\hat{Y_i} - Y_i$)')

# %%
# Plot untrimmed residuals for test set
test_length = 371457
fig = plt.figure(figsize = (18, 12))
_x = np.arange(0, test_length).reshape(test_length, 1)
colors = pl.cm.jet(np.linspace(1, 0, 8))
i = 0

for k in params.keys():
    residual = params[k]['predict'][:test_length] - params[k]['data'][3][:test_length].reshape(test_length, 1)
    plt.plot(_x, residual, color = colors[i], label = params[k]['label'], alpha = 0.7, linewidth = 0.7)
    i += 1

plt.legend(loc = 'best', title = 'Model - # Lags', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Residual', fontsize = 12)
plt.title('Untrimmed Test Residual ($\hat{Y_i} - Y_i$)', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Untrimmed Test Residual ($\\hat{Y_i} - Y_i$)')

# %%
# Plot trimmed residuals for test set
upper_limit = 2000
fig = plt.figure(figsize = (18, 12))
_x = np.arange(0, upper_limit).reshape(upper_limit, 1)
colors = pl.cm.jet(np.linspace(1, 0, 12))
i = 0

for k in params.keys():
    residual = params[k]['predict'][:upper_limit] - params[k]['data'][3][:upper_limit].reshape(upper_limit, 1)
    plt.plot(_x, residual, color = colors[i], label = params[k]['label'], alpha = 0.7, linewidth = 0.7)
    i += 1

plt.legend(loc = 'best', title = 'Model - # Lags', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Residual', fontsize = 12)
plt.title('Trimmed Test Residual ($\hat{Y_i} - Y_i$)', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Trimmed Test Residual ($\\hat{Y_i} - Y_i$)')

# %%
# Plot near_term forecasting residuals for test set
upper_limit = 200
fig = plt.figure(figsize = (18, 12))
_x = np.arange(0, upper_limit).reshape(upper_limit, 1)
colors = pl.cm.jet(np.linspace(1, 0, 12))
i = 0

for k in params.keys():
    residual = params[k]['predict'][:upper_limit] - params[k]['data'][3][:upper_limit].reshape(upper_limit, 1)
    plt.plot(_x, residual, color = colors[i], label = params[k]['label'], alpha = 0.7, linewidth = 0.7)
    i += 1

plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Residual', fontsize = 12)
plt.title('Near-term Forecasting Residual ($\hat{Y_i} - Y_i$)', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Near-term Forecasting Residual ($\\hat{Y_i} - Y_i$)')

# %%
print("Model Errors by Lag Count:")
print()

for k in params.keys():
    print('Model: ' + params[k]['label'] )
    print('   Lag count - [ ' + str(params[k]['n_lags']) + ' ]')
    print('      Train MSE = ' + str(params[k]['MSE_train']) )
    print('      Test MSE = ' + str(params[k]['MSE_test']) )
    print()
# Out:
# Model Errors by Lag Count:
#
# Model: sRNN - 3
#    Lag count - [ 3 ]
#       Train MSE = 0.002024221121567068
#       Test MSE = 0.17603237281238965
#
# Model: sRNN - 5
#    Lag count - [ 5 ]
#       Train MSE = 0.0015713218245207666
#       Test MSE = 0.003050817149813273
#
# Model: sRNN - 7
#    Lag count - [ 7 ]
#       Train MSE = 0.002336415329383304
#       Test MSE = 0.1249214759519463
#
# Model: sRNN - 9
#    Lag count - [ 9 ]
#       Train MSE = 0.0019335028440308185
#       Test MSE = 0.1614106347038754
#
# Model: sGRU - 3
#    Lag count - [ 3 ]
#       Train MSE = 0.0033823294385518935
#       Test MSE = 0.7010158544046209
#
# Model: sGRU - 5
#    Lag count - [ 5 ]
#       Train MSE = 0.0014397606364676744
#       Test MSE = 0.26316418811095127
#
# Model: sGRU - 7
#    Lag count - [ 7 ]
#       Train MSE = 0.0013469073748081481
#       Test MSE = 0.3180044712850365
#
# Model: sGRU - 9
#    Lag count - [ 9 ]
#       Train MSE = 0.0013860664983393986
#       Test MSE = 0.3320429234692467
