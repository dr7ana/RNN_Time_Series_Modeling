# %%
# standard
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
# statsmodels
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA
# os
import os
# sklearn
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
# tf
import tensorflow as tf
# keras
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Layer, LSTM, GRU, SimpleRNN, Dense, Activation, Bidirectional
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
from keras import optimizers
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
from keras.regularizers import l1,l2
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Import btc
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Make pd df
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/NN - 434/btc.csv')

# %%
df.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0            4.39
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# Drop extraneous columns
df.drop(['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume_(BTC)', 'Volume_(Currency)'], axis = 1, inplace = True)
# Drop bottom 3m rows and top 800k
df.drop(df.index[:3000000], axis = 0, inplace = True)
df.drop(df.index[4000000:], axis = 0, inplace = True)
# Reset index; drop column
df.reset_index(drop = True, inplace = True)
# Backfill na's
df.fillna(method = 'backfill', inplace = True)

# %%
# RNN target/features
features = ['Weighted_Price']
target = 'Weighted_Price'

# %%
# Split train sets
train_weight = 0.8
df_split = int(len(df) * train_weight)

train = df.iloc[:df_split]
test = df.iloc[df_split:]

# %%
# Scaling parameters
mu = float(train[features].mean() )
sigma = float(train[features].std() )

# Scale data
train = train[features].apply(lambda x: (x - mu) / sigma)
test = test[features].apply(lambda x: (x - mu) / sigma)

# %%
'''
Function for reshaping data into one-step ahead time series prediction format
    value: feature value to be lagged
    n_steps: number of steps/sequence length
    n_steps_ahead: forecasting horizon
'''

def get_lagged_features(value, n_steps, n_steps_ahead):
    lag_list = []
    for lag in range(n_steps + n_steps_ahead - 1, n_steps_ahead - 1, -1):
        lag_list.append( value.shift(lag) )
    return pd.concat(lag_list, axis = 1)

# %%
'''
Function for altering train/test time-series into n-step lagged data
    _train: train data
    _test: test data
    n_steps: number of lags
'''

def lag_train_test(_train = train, _test = test, n_steps = 3):
    n_steps_ahead = n_steps

    # Transform training input and output data
    col_ords = []
    for i in range(n_steps):
        for j in range(len(features)):
            col_ords.append(i + j * n_steps)

    x_train_list = []
    for f in features:
        x_train_reg = get_lagged_features(train, n_steps, n_steps).dropna()
        x_train_list.append(x_train_reg)
    x_train_reg = pd.concat(x_train_list, axis = 1)
            
    x_train_reg = x_train_reg.iloc[:, col_ords]
    y_train_reg = train.loc[x_train_reg.index, [target]].values
    x_train_reg = np.reshape( x_train_reg.values, ( x_train_reg.shape[0], int( x_train_reg.shape[1] / len(features)), len(features) ) )
    y_train_reg = np.reshape( y_train_reg, (y_train_reg.shape[0], 1, 1))

    # Transform test input and output data
    x_test_list = []
    for f in features:
        x_test_reg = get_lagged_features(test, n_steps, n_steps).dropna()
        x_test_list.append(x_test_reg)
    x_test_reg = pd.concat(x_test_list, axis = 1)

    x_test_reg = x_test_reg.iloc[:, col_ords]
    y_test_reg = test.loc[x_test_reg.index, [target]].values
    x_test_reg = np.reshape( x_test_reg.values, ( x_test_reg.shape[0], int( x_test_reg.shape[1] / len(features)), len(features) ) )
    y_test_reg = np.reshape( y_test_reg, (y_test_reg.shape[0], 1, 1))

    print('Data transformed to have ' + str(n_steps) + ' step-lags...')
    print('   Regularized x training set shape: ' + str(x_train_reg.shape))
    print('   Regularized x testing set shape: ' + str(x_test_reg.shape))
    print('   Regularized y training set shape: ' + str(y_train_reg.shape))
    print('   Regularized y testing set shape: ' + str(y_test_reg.shape))

    return [x_train_reg, x_test_reg, y_train_reg, y_test_reg]

# %%
# Custom activation function
def swish(x):
    return (K.sigmoid(x) * x)

get_custom_objects().update({'swish': Activation(swish)})

# %%
# NN structures - tanh

def _RNN(data = train, n_units = 10, l1_reg = 0, seed = 0, optim = 'adam'):
    model = Sequential()
    model.add( 
        SimpleRNN(n_units,
                  activation = 'tanh', 
                  kernel_initializer = keras.initializers.glorot_uniform(seed), 
                  bias_initializer = keras.initializers.glorot_uniform(seed), 
                  recurrent_initializer = keras.initializers.orthogonal(seed), 
                  kernel_regularizer = l1(l1_reg), 
                  input_shape = (data.shape[1], data.shape[-1]),
                  unroll = True,
                  stateful = False) )  
    model.add(
        Dense(1, 
              kernel_initializer = keras.initializers.glorot_uniform(seed), 
              bias_initializer = keras.initializers.glorot_uniform(seed), 
              kernel_regularizer = l1(l1_reg) ) )
    model.compile(loss = 'mean_squared_error', optimizer = optim)
    return model

def _LSTM(data = train, n_units = 10, l1_reg = 0, seed = 0, optim = 'adam'):
    model = Sequential()
    model.add(
        LSTM(n_units,
             activation = 'tanh',
             kernel_initializer = keras.initializers.glorot_uniform(seed), 
             bias_initializer = keras.initializers.glorot_uniform(seed), 
             recurrent_initializer = keras.initializers.orthogonal(seed), 
             kernel_regularizer = l1(l1_reg), 
             input_shape = (data.shape[1], data.shape[-1]),
             unroll = True,
             stateful = False) )
    model.add(
        Dense(1,
              kernel_initializer = keras.initializers.glorot_uniform(seed), 
              bias_initializer = keras.initializers.glorot_uniform(seed), 
              kernel_regularizer = l1(l1_reg) ) )
    model.compile(loss = 'mean_squared_error', optimizer = optim)
    return model

def _GRU(data = train, n_units = 10, l1_reg = 0, seed = 0, optim = 'adam'):
    model = Sequential()
    model.add(
        GRU(n_units,
             activation = 'tanh',
             kernel_initializer = keras.initializers.glorot_uniform(seed), 
             bias_initializer = keras.initializers.glorot_uniform(seed), 
             recurrent_initializer = keras.initializers.orthogonal(seed), 
             kernel_regularizer = l1(l1_reg), 
             input_shape = (data.shape[1], data.shape[-1]),
             unroll = True,
             stateful = False) )
    model.add(
        Dense(1,
              kernel_initializer = keras.initializers.glorot_uniform(seed), 
              bias_initializer = keras.initializers.glorot_uniform(seed), 
              kernel_regularizer = l1(l1_reg) ) )
    model.compile(loss = 'mean_squared_error', optimizer = optim)
    return model

# %%
# NN structures - SWISH
def _sRNN(data = train,n_units = 10, l1_reg = 0, seed = 0, optim = 'adam'):
    model = Sequential()
    model.add( 
        SimpleRNN(n_units,
                  activation = 'swish', 
                  kernel_initializer = keras.initializers.glorot_uniform(seed), 
                  bias_initializer = keras.initializers.glorot_uniform(seed), 
                  recurrent_initializer = keras.initializers.orthogonal(seed), 
                  kernel_regularizer = l1(l1_reg), 
                  input_shape = (data.shape[1], data.shape[-1]),
                  unroll = True,
                  stateful = False) )  
    model.add(
        Dense(1, 
              kernel_initializer = keras.initializers.glorot_uniform(seed), 
              bias_initializer = keras.initializers.glorot_uniform(seed), 
              kernel_regularizer = l1(l1_reg) ) )
    model.compile(loss = 'mean_squared_error', optimizer = optim)
    return model

def _sLSTM(data = train,n_units = 10, l1_reg = 0, seed = 0, optim = 'adam'):
    model = Sequential()
    model.add(
        LSTM(n_units,
             activation = 'swish',
             kernel_initializer = keras.initializers.glorot_uniform(seed), 
             bias_initializer = keras.initializers.glorot_uniform(seed), 
             recurrent_initializer = keras.initializers.orthogonal(seed), 
             kernel_regularizer = l1(l1_reg), 
             input_shape = (data.shape[1], data.shape[-1]),
             unroll = True,
             stateful = False) )
    model.add(
        Dense(1,
              kernel_initializer = keras.initializers.glorot_uniform(seed), 
              bias_initializer = keras.initializers.glorot_uniform(seed), 
              kernel_regularizer = l1(l1_reg) ) )
    model.compile(loss = 'mean_squared_error', optimizer = optim)
    return model

def _sGRU(data = train, n_units = 10, l1_reg = 0, seed = 0, optim = 'adam'):
    model = Sequential()
    model.add(
        GRU(n_units,
             activation = 'swish',
             kernel_initializer = keras.initializers.glorot_uniform(seed), 
             bias_initializer = keras.initializers.glorot_uniform(seed), 
             recurrent_initializer = keras.initializers.orthogonal(seed), 
             kernel_regularizer = l1(l1_reg), 
             input_shape = (data.shape[1], data.shape[-1]),
             unroll = True,
             stateful = False) )
    model.add(
        Dense(1,
              kernel_initializer = keras.initializers.glorot_uniform(seed), 
              bias_initializer = keras.initializers.glorot_uniform(seed), 
              kernel_regularizer = l1(l1_reg) ) )
    model.compile(loss = 'mean_squared_error', optimizer = optim)
    return model

# %%
# Hyperparameters
n_epoches = 50
batch_size = 1000

# %%
# Implement early stopping monitor to speed up cross validation
es = EarlyStopping(monitor = 'loss', mode = 'min', verbose = 1, patience = 100, 
                   min_delta = 1e-7, restore_best_weights = True)

# %%
# NN models
params = {
    'rnn_3lag': {'model':'', 'function':_RNN, 'data':[], 'H':12, 'l1_reg':0.00001, 'n_lags':3, 'color':'', 'label':'RNN - 3', 'history':''},
    'rnn_5lag': {'model':'', 'function':_RNN, 'data':[], 'H':12, 'l1_reg':0.00001, 'n_lags':5, 'color':'', 'label':'RNN - 5', 'history':''},
    'lstm_3lag': {'model':'', 'function':_LSTM, 'data':[], 'H':10, 'l1_reg':0.00005, 'n_lags':3, 'color':'', 'label':'LSTM - 3', 'history':''},
    'lstm_5lag': {'model':'', 'function':_LSTM, 'data':[], 'H':10, 'l1_reg':0.00005, 'n_lags':5, 'color':'', 'label':'LSTM - 5', 'history':''},
    'gru_3lag': {'model':'', 'function':_GRU, 'data':[], 'H':8, 'l1_reg':0.00005, 'n_lags':3, 'color':'', 'label':'GRU - 3', 'history':''},
    'gru_5lag': {'model':'', 'function':_GRU, 'data':[], 'H':8, 'l1_reg':0.00005, 'n_lags':5, 'color':'', 'label':'GRU - 5', 'history':''},
    'srnn_3lag': {'model':'', 'function':_sRNN, 'data':[], 'H':10, 'l1_reg':0.0001, 'n_lags':3, 'color':'', 'label':'sRNN - 3', 'history':''},
    'srnn_5lag': {'model':'', 'function':_sRNN, 'data':[], 'H':10, 'l1_reg':0.0001, 'n_lags':5, 'color':'', 'label':'sRNN - 5', 'history':''},
    'slstm_3lag': {'model':'', 'function':_sLSTM, 'data':[], 'H':8, 'l1_reg':0.00005, 'n_lags':3, 'color':'', 'label':'sLSTM - 3', 'history':''},
    'slstm_5lag': {'model':'', 'function':_sLSTM, 'data':[], 'H':8, 'l1_reg':0.00005, 'n_lags':5, 'color':'', 'label':'sLSTM - 5', 'history':''},
    'sgru_3lag': {'model':'', 'function':_sGRU, 'data':[], 'H':12, 'l1_reg':0.00001, 'n_lags':3, 'color':'', 'label':'sGRU - 3', 'history':''},
    'sgru_5lag': {'model':'', 'function':_sGRU, 'data':[], 'H':12, 'l1_reg':0.00001, 'n_lags':5, 'color':'', 'label':'sGRU - 5', 'history':''},
}

# %%
# Produce lagged data; store in params

for k in params.keys():
    params[k]['data'] = lag_train_test(train, test, params[k]['n_lags'])
# Out:
# Data transformed to have 3 step-lags...
#    Regularized x training set shape: (1485896, 3, 1)
#    Regularized x testing set shape: (371471, 3, 1)
#    Regularized y training set shape: (1485896, 1, 1)
#    Regularized y testing set shape: (371471, 1, 1)
# Data transformed to have 5 step-lags...
#    Regularized x training set shape: (1485892, 5, 1)
#    Regularized x testing set shape: (371467, 5, 1)
#    Regularized y training set shape: (1485892, 1, 1)
#    Regularized y testing set shape: (371467, 1, 1)
# Data transformed to have 3 step-lags...
#    Regularized x training set shape: (1485896, 3, 1)
#    Regularized x testing set shape: (371471, 3, 1)
#    Regularized y training set shape: (1485896, 1, 1)
#    Regularized y testing set shape: (371471, 1, 1)
# Data transformed to have 5 step-lags...
#    Regularized x training set shape: (1485892, 5, 1)
#    Regularized x testing set shape: (371467, 5, 1)
#    Regularized y training set shape: (1485892, 1, 1)
#    Regularized y testing set shape: (371467, 1, 1)
# Data transformed to have 3 step-lags...
#    Regularized x training set shape: (1485896, 3, 1)
#    Regularized x testing set shape: (371471, 3, 1)
#    Regularized y training set shape: (1485896, 1, 1)
#    Regularized y testing set shape: (371471, 1, 1)
# Data transformed to have 5 step-lags...
#    Regularized x training set shape: (1485892, 5, 1)
#    Regularized x testing set shape: (371467, 5, 1)
#    Regularized y training set shape: (1485892, 1, 1)
#    Regularized y testing set shape: (371467, 1, 1)
# Data transformed to have 3 step-lags...
#    Regularized x training set shape: (1485896, 3, 1)
#    Regularized x testing set shape: (371471, 3, 1)
#    Regularized y training set shape: (1485896, 1, 1)
#    Regularized y testing set shape: (371471, 1, 1)
# Data transformed to have 5 step-lags...
#    Regularized x training set shape: (1485892, 5, 1)
#    Regularized x testing set shape: (371467, 5, 1)
#    Regularized y training set shape: (1485892, 1, 1)
#    Regularized y testing set shape: (371467, 1, 1)
# Data transformed to have 3 step-lags...
#    Regularized x training set shape: (1485896, 3, 1)
#    Regularized x testing set shape: (371471, 3, 1)
#    Regularized y training set shape: (1485896, 1, 1)
#    Regularized y testing set shape: (371471, 1, 1)
# Data transformed to have 5 step-lags...
#    Regularized x training set shape: (1485892, 5, 1)
#    Regularized x testing set shape: (371467, 5, 1)
#    Regularized y training set shape: (1485892, 1, 1)
#    Regularized y testing set shape: (371467, 1, 1)
# Data transformed to have 3 step-lags...
#    Regularized x training set shape: (1485896, 3, 1)
#    Regularized x testing set shape: (371471, 3, 1)
#    Regularized y training set shape: (1485896, 1, 1)
#    Regularized y testing set shape: (371471, 1, 1)
# Data transformed to have 5 step-lags...
#    Regularized x training set shape: (1485892, 5, 1)
#    Regularized x testing set shape: (371467, 5, 1)
#    Regularized y training set shape: (1485892, 1, 1)
#    Regularized y testing set shape: (371467, 1, 1)

# %%
# Train
for k in params.keys():
    tf.random.set_seed(0)
    model = params[k]['function'](params[k]['data'][0], params[k]['H'], params[k]['l1_reg'] )
    params[k]['history'] = model.fit(params[k]['data'][0], params[k]['data'][2], epochs = n_epoches, 
                                     batch_size = batch_size, callbacks = [es], shuffle = False )
    params[k]['model'] = model
# Out:
# Epoch 1/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0813
# Epoch 2/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0311
# Epoch 3/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0171
# Epoch 4/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0095
# Epoch 5/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0057
# Epoch 6/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0042
# Epoch 7/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0034
# Epoch 8/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0031
# Epoch 9/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0031
# Epoch 10/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0032
# Epoch 11/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0034
# Epoch 12/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0031
# Epoch 13/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0030
# Epoch 14/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0028
# Epoch 15/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0026
# Epoch 16/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0024
# Epoch 17/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0022
# Epoch 18/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0020
# Epoch 19/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0022
# Epoch 20/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0019
# Epoch 21/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0018
# Epoch 22/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0016
# Epoch 23/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0015
# Epoch 24/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0017
# Epoch 25/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0014
# Epoch 26/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0015
# Epoch 27/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0013
# Epoch 28/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0013
# Epoch 29/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0012
# Epoch 30/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0011
# Epoch 31/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0013
# Epoch 32/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0012
# Epoch 33/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0011
# Epoch 34/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 0.0011
# Epoch 35/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 9.8558e-04
# Epoch 36/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 9.6143e-04
# Epoch 37/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 8.4465e-04
# Epoch 38/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 7.8774e-04
# Epoch 39/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 6.9555e-04
# Epoch 40/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 6.1377e-04
# Epoch 41/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 5.1809e-04
# Epoch 42/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 4.5495e-04
# Epoch 43/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 4.0407e-04
# Epoch 44/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 3.9873e-04
# Epoch 45/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 4.1244e-04
# Epoch 46/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 4.0340e-04
# Epoch 47/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 3.9565e-04
# Epoch 48/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 4.0390e-04
# Epoch 49/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 3.8271e-04
# Epoch 50/50
# 1486/1486 [==============================] - 3s 2ms/step - loss: 3.9465e-04
# Epoch 1/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0827
# Epoch 2/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0289
# Epoch 3/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0138
# Epoch 4/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0082
# Epoch 5/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0059
# Epoch 6/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0055
# Epoch 7/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0050
# Epoch 8/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0048
# Epoch 9/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0046
# Epoch 10/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0043
# Epoch 11/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0043
# Epoch 12/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0044
# Epoch 13/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0042
# Epoch 14/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0037
# Epoch 15/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0028
# Epoch 16/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0022
# Epoch 17/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0020
# Epoch 18/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0021
# Epoch 19/50
# 1486/1486 [==============================] - 4s 2ms/step - loss: 0.0026
# Epoch 20/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0016
# Epoch 21/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0014
# Epoch 22/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0012
# Epoch 23/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0011
# Epoch 24/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0012
# Epoch 25/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0016
# Epoch 26/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0014
# Epoch 27/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 0.0014
# Epoch 28/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.8236e-04
# Epoch 29/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.6794e-04
# Epoch 30/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 9.6511e-04
# Epoch 31/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.2961e-04
# Epoch 32/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 8.0658e-04
# Epoch 33/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 7.5155e-04
# Epoch 34/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.4614e-04
# Epoch 35/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 6.5378e-04
# Epoch 36/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 5.7709e-04
# Epoch 37/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 5.5728e-04
# Epoch 38/50
# 1486/1486 [==============================] - 4s 3ms/step - loss: 5.3151e-04
# Epoch 39/50
# 1486/1486 [==============================] - 4s 3ms/step - loss:
50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.4108e-04
# Epoch 37/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3995e-04
# Epoch 38/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3923e-04
# Epoch 39/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3847e-04
# Epoch 40/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3776e-04
# Epoch 41/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3721e-04
# Epoch 42/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3721e-04
# Epoch 43/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.3815e-04
# Epoch 44/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.4033e-04
# Epoch 45/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.4397e-04
# Epoch 46/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.4912e-04
# Epoch 47/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.5477e-04
# Epoch 48/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.5990e-04
# Epoch 49/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.6424e-04
# Epoch 50/50
# 1486/1486 [==============================] - 5s 3ms/step - loss: 2.6754e-04
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 1486/1486 [==============================] - 7s 4ms/step - loss: 0.0664
# Epoch 2/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.2035e-04
# Epoch 3/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.5438e-04
# Epoch 4/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.6358e-04
# Epoch 5/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.6079e-04
# Epoch 6/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.7698e-04
# Epoch 7/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.7931e-04
# Epoch 8/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.7832e-04
# Epoch 9/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.7653e-04
# Epoch 10/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.8116e-04
# Epoch 11/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.8956e-04
# Epoch 12/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.0419e-04
# Epoch 13/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.2670e-04
# Epoch 14/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.5930e-04
# Epoch 15/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 4.1435e-04
# Epoch 16/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 4.4385e-04
# Epoch 17/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 4.3213e-04
# Epoch 18/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 4.1352e-04
# Epoch 19/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.9921e-04
# Epoch 20/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.9113e-04
# Epoch 21/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.8953e-04
# Epoch 22/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.9147e-04
# Epoch 23/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.9279e-04
# Epoch 24/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.9097e-04
# Epoch 25/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.8635e-04
# Epoch 26/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.8060e-04
# Epoch 27/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.7412e-04
# Epoch 28/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.6927e-04
# Epoch 29/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.6865e-04
# Epoch 30/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.6832e-04
# Epoch 31/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.6848e-04
# Epoch 32/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.7005e-04
# Epoch 33/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.7093e-04
# Epoch 34/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.6930e-04
# Epoch 35/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.6444e-04
# Epoch 36/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.5715e-04
# Epoch 37/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.4902e-04
# Epoch 38/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.4098e-04
# Epoch 39/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.3341e-04
# Epoch 40/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.2632e-04
# Epoch 41/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.1964e-04
# Epoch 42/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.1373e-04
# Epoch 43/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.0870e-04
# Epoch 44/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.0458e-04
# Epoch 45/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 3.0160e-04
# Epoch 46/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.9976e-04
# Epoch 47/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.9886e-04
# Epoch 48/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.9796e-04
# Epoch 49/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.9554e-04
# Epoch 50/50
# 1486/1486 [==============================] - 6s 4ms/step - loss: 2.9120e-04

# %%
# Prediction on test and train data with NN models
for k in params.keys():
    step_lag = params[k]['n_lags'] + params[k]['n_lags'] - 1
    model = params[k]['model']
    model.summary()

    params[k]['MSE_train'] = mean_squared_error(train[features][step_lag:], 
                                                model.predict(params[k]['data'][0], verbose = 1))
    params[k]['predict'] = model.predict(params[k]['data'][1], verbose = 1)
    params[k]['MSE_test'] = mean_squared_error(test[features][step_lag:],
                                               params[k]['predict'])
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_4 (SimpleRNN)    (None, 12)                168
#
#  dense_10 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 56s 1ms/step
# 11609/11609 [==============================] - 14s 1ms/step
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_5 (SimpleRNN)    (None, 12)                168
#
#  dense_11 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 60s 1ms/step
# 11609/11609 [==============================] - 15s 1ms/step
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 10)                480
#
#  dense_12 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 64s 1ms/step
# 11609/11609 [==============================] - 16s 1ms/step
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 10)                480
#
#  dense_13 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 72s 2ms/step
# 11609/11609 [==============================] - 18s 2ms/step
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_2 (GRU)                 (None, 8)                 264
#
#  dense_14 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 69s 1ms/step
# 11609/11609 [==============================] - 18s 2ms/step
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 8)                 264
#
#  dense_15 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 81s 2ms/step
# 11609/11609 [==============================] - 20s 2ms/step
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_6 (SimpleRNN)    (None, 10)                120
#
#  dense_16 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 57s 1ms/step
# 11609/11609 [==============================] - 14s 1ms/step
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_7 (SimpleRNN)    (None, 10)                120
#
#  dense_17 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 61s 1ms/step
# 11609/11609 [==============================] - 15s 1ms/step
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 8)                 320
#
#  dense_18 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 329
# Trainable params: 329
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 66s 1ms/step
# 11609/11609 [==============================] - 16s 1ms/step
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 8)                 320
#
#  dense_19 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 329
# Trainable params: 329
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 74s 2ms/step
# 11609/11609 [==============================] - 19s 2ms/step
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_4 (GRU)                 (None, 12)                540
#
#  dense_20 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 553
# Trainable params: 553
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 69s 1ms/step
# 11609/11609 [==============================] - 17s 1ms/step
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_5 (GRU)                 (None, 12)                540
#
#  dense_21 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 553
# Trainable params: 553
# Non-trainable params: 0
# _________________________________________________________________
# 46435/46435 [==============================] - 82s 2ms/step
# 11609/11609 [==============================] - 21s 2ms/step

# %%
# Plot training loss by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(0, 1, 12))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['loss'], color = colors[i],
             label = params[k]['label'], alpha = 0.8)
    i += 1
    

plt.yscale('log')
plt.legend(loc = 'best', title = 'Model - # Lags', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('$\log{(loss)}$', fontsize = 12)
plt.title('Training Loss By Epoch', fontsize = 18)

plt.show()

# %%
# Plot untrimmed residuals for test set
test_length = 371457
fig = plt.figure(figsize = (18, 12))
_x = np.arange(0, test_length).reshape(test_length, 1)
colors = pl.cm.jet(np.linspace(1, 0, 12))
i = 0

for k in params.keys():
    residual = params[k]['predict'][:test_length] - params[k]['data'][3][:test_length].reshape(test_length, 1)
    plt.plot(_x, residual, color = colors[i], label = params[k]['label'], alpha = 0.7, linewidth = 0.7)
    i += 1

plt.legend(loc = 'best', title = 'Model - # Lags', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Residual', fontsize = 12)
plt.title('Untrimmed Test Residual ($\hat{Y_i} - Y_i$)', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Untrimmed Test Residual ($\\hat{Y_i} - Y_i$)')

# %%
# Plot trimmed residuals for test set
upper_limit = 2000
fig = plt.figure(figsize = (18, 12))
_x = np.arange(0, upper_limit).reshape(upper_limit, 1)
colors = pl.cm.jet(np.linspace(1, 0, 12))
i = 0

for k in params.keys():
    residual = params[k]['predict'][:upper_limit] - params[k]['data'][3][:upper_limit].reshape(upper_limit, 1)
    plt.plot(_x, residual, color = colors[i], label = params[k]['label'], alpha = 0.7, linewidth = 0.7)
    i += 1

plt.legend(loc = 'best', title = 'Model - # Lags', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Residual', fontsize = 12)
plt.title('Trimmed Test Residual ($\hat{Y_i} - Y_i$)', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Trimmed Test Residual ($\\hat{Y_i} - Y_i$)')

# %%
# Plot near_term forecasting residuals for test set
upper_limit = 200
fig = plt.figure(figsize = (18, 12))
_x = np.arange(0, upper_limit).reshape(upper_limit, 1)
colors = pl.cm.jet(np.linspace(1, 0, 12))
i = 0

for k in params.keys():
    residual = params[k]['predict'][:upper_limit] - params[k]['data'][3][:upper_limit].reshape(upper_limit, 1)
    plt.plot(_x, residual, color = colors[i], label = params[k]['label'], alpha = 0.7, linewidth = 0.7)
    i += 1

plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Time', fontsize = 12)
plt.ylabel('Residual', fontsize = 12)
plt.title('Near-term Forecasting Residual ($\hat{Y_i} - Y_i$)', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Near-term Forecasting Residual ($\\hat{Y_i} - Y_i$)')

# %%
print("Model Errors by Lag Count:")
print()

for k in params.keys():
    print('Model: ' + params[k]['label'] )
    print('   Lag count - [ ' + str(params[k]['n_lags']) + ' ]')
    print('      Train MSE = ' + str(params[k]['MSE_train']) )
    print('      Test MSE = ' + str(params[k]['MSE_test']) )
    print()
# Out:
# Model Errors by Lag Count:
#
# Model: RNN - 3
#    Lag count - [ 3 ]
#       Train MSE = 0.00021274545050485252
#       Test MSE = 32.73016336910044
#
# Model: RNN - 5
#    Lag count - [ 5 ]
#       Train MSE = 0.0035520857360989513
#       Test MSE = 31.06985528702865
#
# Model: LSTM - 3
#    Lag count - [ 3 ]
#       Train MSE = 0.003746493403665293
#       Test MSE = 30.207403949024833
#
# Model: LSTM - 5
#    Lag count - [ 5 ]
#       Train MSE = 0.0019156189528193644
#       Test MSE = 32.517044715655814
#
# Model: GRU - 3
#    Lag count - [ 3 ]
#       Train MSE = 0.0018160147184502183
#       Test MSE = 32.32137389398414
#
# Model: GRU - 5
#    Lag count - [ 5 ]
#       Train MSE = 0.0024061495986007733
#       Test MSE = 32.25868395836636
#
# Model: sRNN - 3
#    Lag count - [ 3 ]
#       Train MSE = 0.0020183333301026355
#       Test MSE = 0.1757872288316143
#
# Model: sRNN - 5
#    Lag count - [ 5 ]
#       Train MSE = 0.0015648926511321202
#       Test MSE = 0.003008651888354583
#
# Model: sLSTM - 3
#    Lag count - [ 3 ]
#       Train MSE = 0.0008534238471086059
#       Test MSE = 20.91110969054325
#
# Model: sLSTM - 5
#    Lag count - [ 5 ]
#       Train MSE = 0.001074571436302793
#       Test MSE = 34.89574246312721
#
# Model: sGRU - 3
#    Lag count - [ 3 ]
#       Train MSE = 0.003382043675123726
#       Test MSE = 0.7007535154585849
#
# Model: sGRU - 5
#    Lag count - [ 5 ]
#       Train MSE = 0.00143948337918158
#       Test MSE = 0.2630975496850909

# %%
print('Near-term Forecasting Accuracy')
print()

for k in params.keys():
    print('Model: ' + params[k]['label'] )
    temp = mean_squared_error(test[features][step_lag : 200], params[k]['predict'][step_lag : 200])
    print('   Lag count [ ' + str(params[k]['n_lags']) + ' ] - MSE = ' + str(temp))
    print()
# Out:
# Near-term Forecasting Accuracy
#
# Model: RNN - 3
#    Lag count [ 3 ] - MSE = 2.5131861643950156e-06
#
# Model: RNN - 5
#    Lag count [ 5 ] - MSE = 3.2443273459649666e-06
#
# Model: LSTM - 3
#    Lag count [ 3 ] - MSE = 1.3813942331299067e-06
#
# Model: LSTM - 5
#    Lag count [ 5 ] - MSE = 2.126064989196134e-06
#
# Model: GRU - 3
#    Lag count [ 3 ] - MSE = 1.326157265657973e-06
#
# Model: GRU - 5
#    Lag count [ 5 ] - MSE = 2.6789449019529112e-06
#
# Model: sRNN - 3
#    Lag count [ 3 ] - MSE = 1.243664251620488e-06
#
# Model: sRNN - 5
#    Lag count [ 5 ] - MSE = 2.6875832663130697e-06
#
# Model: sLSTM - 3
#    Lag count [ 3 ] - MSE = 2.6423911845632287e-07
#
# Model: sLSTM - 5
#    Lag count [ 5 ] - MSE = 4.972162262688805e-07
#
# Model: sGRU - 3
#    Lag count [ 3 ] - MSE = 8.026749116612311e-07
#
# Model: sGRU - 5
#    Lag count [ 5 ] - MSE = 1.548279772555091e-06
